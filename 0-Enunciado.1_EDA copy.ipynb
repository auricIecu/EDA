# %% [markdown]
# # EXPLORATORY DATA ANALYSIS EDA

# %% [markdown]
# ![EDA.png](./img/steps_EDA.png)

# %% [markdown]
# # Proyecto módulo Data Analysis
# En este proyecto vas a aplicar todo lo aprendido en el Fundamentals y el módulo de Data Analysis del bootcamp. Tendrás que realizar un análisis exploratorio de datos y presentar los resultados. Ten en cuenta lo siguiente:
#
# * **Miembros**: El proyecto es individual
# * **Datos**: Tienes que conseguir los datos por tu cuenta (ver abajo)
# * **Fecha límite**: Viernes 4 de Abril a las 9.00h a través del campus y ese mismo día son las presentaciones. Tendremos dos entregas previas (Viernes 28 de Marzo a las 9.00h con un punto de partida de tema, hipótesis y datasets. El Jueves 3 de Abril a las 9.00h con el repositorio de github).
#
#
# ## Objetivo
# Lo que queremos mediante este tipo de análisis es resolver un problema real apoyándonos en datos, por lo que tendrás que plantearte primero qué es lo que quieres resolver, y a partir de ahí identificar fuentes de datos e ir trabajando con ellos para acabar llegando a una conclusión. Plantea tus hipótesis antes de realizar el análisis exploratorio y después verifica si se han cumplido, o si has descubierto mediante los datos que lo que ocurría era justamente lo opuesto a lo que pensabas.
#
#
# ## Evaluación
# * **Presentación** máximo 10 minutos donde expondrás tu caso (ver apartado Presentación)
# * **Memoria** un jupyter notebook donde explicarás el desarrollo del proyecto con markdown y código de python. (Introducción, Fuentes de datos, Limpiezas, Desarrollo análisis, Medidas estadísticas, Visualizaciones, Conclusiones,..)
# * **Código** hay que entregar todo el código desarrollado. También se tiene en cuenta (tipo solución, documentación...)
# * **Subir el proyecto a tu GitHub personal**. Este gran esfuerzo tiene que ser compartido, y te recomiendo que te crees un repositorio en GitHub para ir añadiendo tus proyectos personales. En caso de que el proyecto se componga de datos sensibles o no se quiera publicar, se puede mantener en repositorio privado (consultar profesores).
#
#
# ## Entregable
# El enlace al repositorio de github que habrá que subir a Google Classroom. Debe constar:
# * Presentación
# * Memoria
# * Código
#
# El codigo deberá seguir la siguiente estructura de carpetas:
# 1. src/: aquí irá todo el código
# 2. src/data: todos los archivos de datos utilizados en el analisis. No subir a GitHub archivos demasiado pesados.
# 3. src/notebooks: los notebooks usados para pruebas.
# 4. src/utils: todos los modulos, funciones auxiliares o clases creados para el desarrollo del proyecto.
# 5. src/memoria.ipynb: en este notebook tendrás que resumir de forma clara y ordenada todos los pasos de la analítica.
#
# **GitHub**: hay que crear un README con una descripción de tu proyecto. Breve. El objetivo de este README es enterarse de forma rápida de qué va tu proyecto y qué tecnologías has utilizado para llevarlo a cabo, no es más que un escaparate de tu trabajo. Hay que ir documentando bien los trabajos para acabar el bootcamp con un buen portfolio. En [este enlace](https://github.com/alexhuang1117/Data-Science-Portfolio) tienes un ejemplo de cómo tener documentados los proyectos en tu GitHub. Encontrarás en el notebook de markdown todo lo que necesitas para crear un README decente.

# %% [markdown]
# ## Presentación
# Puesto que en la vida real la mayoría de presentaciones se realizan a un público no técnico, ésta no va a ser menos. Si tienes que explicar algo técnico, cuéntalo, pero para alguien que no sabe lo que significa. Por ejemplo, ¿cómo contarías qué es una matriz de correlación? **No queremos ver código**, ni cómo estructuraste el proyecto en carpetas, ni cómo de difícil ha sido limpiarlo. Al cliente/tu jefe le da igual :). Explicar cosas técnicas lleva tiempo por lo que piensa muy bien en lo que vas a decir y en cómo lo sintetizarás.
#
# Tendrás que exponer bien tu caso de uso con su contexto, explicar qué transformaciones y línea de análisis has abordado, y acabar la presentación con unas conclusiones y oportunidades que nos brinda el proyecto, para cerrar el plantemiento inicial del caso de uso.
#
# **¿Formatos de la presentación?** Nada de Notebooks. Formato presentación en PowerPoint, Google Slides, Prezi o la plataforma que mejor conozcas, siendo perfectamente combinable con un dashboard.
#
# **Consejos**: Si usas un PowerPoint... será tu apoyo a la hora de presentar, aquí el protagonista es tu discurso. Por favor, que la presentación no sea un conjunto de puntos inconexos. Intenta llevar un hilo, como si de una historia se tratase. Véndete, destaca las fortalezas de tu trabajo sobre las debilidades. Interactúa con el público. Si vas a contar algo de negocio, ¿puedes traducirlo a números? ¿Qué impacto tendrá tu analítica?. Muestra algunos datos concretos (estadísticos simples) para justificar tu business case o para cerrar tu presentación. Si has elegido una temática que está acorde con tus gustos/background, aprovecha al principio para contarlo y empatizar mucho más con el público. Si vas a hacer una demo, grábala por si te falla algo en la presentación (conexión a Internet). Prepárate las respuestas a algunas posibles preguntas en un anexo de la presentación.
#
# **NOTA**: existen muchas plantillas gratuitas en la web para hacer presentaciones. [Aquí tienes unas cuantas](https://www.free-powerpoint-templates-design.com/free-powerpoint-templates-design/).
#
#
# ## Pasos del proyecto
#
# 1. Elegir temática
#     1. **Elegir una temática y buscar datos en función de la misma**. Puede ocurrir que no encuentres datos que te sirvan para tu propósito, o que tengas que conseguirlos mediante APIs, scrapping, descarga de BBDD.... No obstante, esta opción es la que más se asemejaría a un caso real, ya que una gran problemática en este tipo de proyectos es encontrar datos.
#
#     2. **Directamente ir a páginas de datos abiertos y escoger un dataset de tu interés**. Si no tienes clara la temática puedes buscar en alguno de los enlaces de datos (recomendable Kaggle) y escoger un tema que te motive.
#
# 2. Obtención de datos. ¿Puedes llevar a cabo el proyecto con estos datos?
# 3. Define tu hipótesis. ¿Qué piensas que puedes analizar de estos datos? ¿Qué vas a poder resolver? ¿Cómo lo vas a llevar a cabo? (**Viernes 20 de Diciembre**). Podrás utilizar el periodo de navidades para terminar de validarlo y pivotar a otro tema.
# 4. Preprocesado: obtén todos los datos de las diferentes fuentes que hayas utilizado, juntalos y ponlos en un formato entendible.
# 5. Limpia los datos: transformaciones, duplicados, missings, columnas inútiles...
# 6. Exploratorio: obtén todos los estadísticos y gráficos que necesites para entender bien tu dataset y apoyar tus argumentos.
# 7. Concluye con tu análisis si estabas o no en lo cierto acerca de tu planteamiento y tu hipótesis.
# 8. Crea un dashboard para representar tu análisis exploratorio si lo consideras necesario.
# 9. Crea una presentación con un hilo conductor sobre tu análisis exploratorio
# 10. Documenta tu proyecto y súbelo a GitHub.

# %% [markdown]
# ## Datos
# ¿De dónde saco los datos? Posibles fuentes:
# - [Web de datos abiertos del gobierno](https://datos.gob.es/)
# - [OpenStreetMap](https://wiki.openstreetmap.org/wiki/API). Datos de ubicaciones (como Google Maps) abiertos
# - [Obtención de datos bursátiles](https://financetrain.com/best-python-librariespackages-finance-financial-data-scientists/)
# - [ESRI Datos abiertos España](https://opendata.esri.es/)
# - [INE](https://www.ine.es/nomen2/ficheros.do)
# - [Red.es](https://www.red.es/redes/es/que-hacemos/datos-abiertos)
# - [Datos abiertos gobierno](https://www.hacienda.gob.es/es-ES/GobiernoAbierto/Datos%20Abiertos/Paginas/Catalogodedatosabiertos.aspx)
# - [Ayuntamiento de Madrid](https://datos.madrid.es/portal/site/egob/)
# - [Ayuntamiento de Barcelona](https://opendata-ajuntament.barcelona.cat/es)
# - [Metro de Madrid](https://data-crtm.opendata.arcgis.com/)
# - [Portal datos europeo I](https://data.europa.eu/euodp/es/home)
# - [Portal datos europeo II](https://www.europeandataportal.eu/data/datasets?locale=en&minScoring=0)
# - [Google Dataset Search](https://datasetsearch.research.google.com/)
# - [Indicadores macro mundiales](https://databank.worldbank.org/home)
# - [Indicadores macro mundiales](https://ilostat.ilo.org/data/country-profiles/)
# - [Amplio repositorio de Datasets](https://datacommons.org/)
# - [Datos macro mundiales](https://www.gapminder.org/data/)
# - [GitHub con gran cantidad de APIs públicas](https://github.com/public-apis/public-apis)
# - [Datos sobre migraciónn](https://migrationdataportal.org/es/node/2955)
# - [Web de datos abiertos de España](https://www.epdata.es/)
# - [Redapi: Plataforma de APIs con amplia capa gratuita](https://rapidapi.com/blog/most-popular-api/)
# - [Artículo para trabajar con histórico de bolsa](https://towardsdatascience.com/how-to-get-stock-data-using-python-c0de1df17e75)
# - [Otro gran repo de datasets](https://www.paperswithcode.com/datasets)
# - [API de Idealista](https://www.idealista.com/data/productos/desarrollo/api-de-testigos)
# - [API de Booking](https://developers.booking.com/api/index.html)
# - [API de Tripadvisor](http://developer-tripadvisor.com/content-api/)
# - [API de Facebook](https://developers.facebook.com/docs/apis-and-sdks?locale=es_ES)
# - [API de Twitter](https://developer.twitter.com/en/docs)
# - [API de Instagram](https://www.instagram.com/developer/)
# - [APIs de Google Maps](https://cloud.google.com/maps-platform?hl=es)
# - [Google Timeline](https://www.google.es/maps/timeline?pb). Todo tu registro de actividad de Google, como los lugares que has visitado
#
# - [Alexa. Tráfico de webs](https://www.alexa.com/siteinfo)
# - [Catastro](https://ovc.catastro.meh.es/ovcservweb/OVCSWLocalizacionRC/OVCCoordenadas.asmx)
# - [Airbnb](http://insideairbnb.com/index.html)
# - Web scrapping. Acceso automatizado a cualquier web.
# - Kaggle: página con competiciones de data scientists. Muchísimos datasets.
# - QPython 3L: APP para ejecutar código Python en el movil. Podrás sacar datos de tu actividad con el teléfono (horarios, geoposicionamiento)
# - Coronavirus. Se están empezando a librerar muchísimos datasets con datos del coronavirus en todo el mundo. En Kaggle hay varios.
#
#
#
# Si tienes algún tema sobre el que quieras investigar, y no encaja con ninguno de los enlaces propuestos, consúltalo con los profesores para investigar de dónde podríamos sacar datos para ese análisis.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <h1>Data importaciones UREA a Ecuador 2009-2024</h1>

# %% [markdown]
# En la casilla siguiente me bajare la data de las importaciones de Urea a Ecuador del 2009 al 2024

# %%
data1 = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data /Importaciones UREA/01:01:2009 - 31:12:2011.csv") 
data2 = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data /Importaciones UREA/01:12:2012-31:12:2014.csv") 
data3 = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data /Importaciones UREA/01:01:2015-31:12:2015.csv") 
data4 = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data /Importaciones UREA/01:01:2016-31:12:2018.csv") 
data5 = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data /Importaciones UREA/01:01:2019-31:12:2019.csv") 
data6 = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data /Importaciones UREA/01:01:2020-31:12:2022.csv") 
data7 = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data /Importaciones UREA/01:01:2023-31:12:2023.csv") 
data8 = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data /Importaciones UREA/01:01:2024-12:31:2024.csv")

# %% [markdown]
# Ahora concatenare todos estos datos en orden descendente

# %%
data_total_raw_importaciones_urea = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8], 
                       axis=0,           
                       ignore_index=True)

# %%
data_total_raw_importaciones_urea.to_csv('Data_2/data_total_raw_importaciones_urea.csv')

# %% [markdown]
# Con esta funcion puedo visualizar todas las columnas

# %%
pd.options.display.max_columns = None
data_total_raw_importaciones_urea
# Out:
#                                           RAZON SOCIAL  \
# 0                                         DELCORP S.A.
# 1     DUPOCSA PROTECTORES QUIMICOS PARA EL CAMPO S. A.
# 2                        BANCO NACIONAL DE FOMENTO BNF
# 3     DUPOCSA PROTECTORES QUIMICOS PARA EL CAMPO S. A.
# 4     DUPOCSA PROTECTORES QUIMICOS PARA EL CAMPO S. A.
# ...                                                ...
# 1982                                   PRECISAGRO S.A.
# 1983                                   PRECISAGRO S.A.
# 1984                               YARECUADOR CIA LTDA
# 1985                               YARECUADOR CIA LTDA
# 1986  QUIMICA INDUSTRIAL MONTALVO AGUILAR QUIMASA S.A.
#
#                                           POTENCIAL UNO NOMBRE COMERCIAL  \
# 0     SERVICIOS AGRICOLAS SOCIEDAD ANONIMA COMERCIAL...     DELCORP S.A.
# 1     SERVICIOS AGRICOLAS SOCIEDAD ANONIMA COMERCIAL...              NaN
# 2     SERVICIOS AGRICOLAS SOCIEDAD ANONIMA COMERCIAL...              NaN
# 3     SERVICIOS AGRICOLAS SOCIEDAD ANONIMA COMERCIAL...              NaN
# 4     SERVICIOS AGRICOLAS SOCIEDAD ANONIMA COMERCIAL...              NaN
# ...                                                 ...              ...
# 1982                                                NaN              NaN
# 1983                                                NaN              NaN
# 1984                                                NaN              NaN
# 1985                                                NaN              NaN
# 1986                                                NaN              NaN
#
#                 RUC                                     CONSIGNATARIO  \
# 0      991265414001                                               NaN
# 1      990856583001                                               NaN
# 2     1760002790001                                               NaN
# 3      990856583001                                               NaN
# 4      990856583001                                               NaN
# ...             ...                                               ...
# 1982  1792522005001                                               NaN
# 1983  1792522005001                                               NaN
# 1984  1792028140001                             YARECUADOR CIA. LTDA.
# 1985  1792028140001                             YARECUADOR CIA. LTDA.
# 1986  1790580202001  QUIMICA INDUSTRIAL MONTALVO AGUILAR QUIMASA S.A.
#
#      POSICION ARANCELARIA  CODIGO COMPLEMENTARIO  CODIGO SUPLEMENTARIO  \
# 0           3102.10.10.00                      0                     0
# 1           3102.10.10.00                      0                     0
# 2           3102.10.10.00                      0                     0
# 3           3102.10.10.00                      0                     0
# 4           3102.10.10.00                      0                     0
# ...                   ...                    ...                   ...
# 1982        3102.10.10.00                      0                     1
# 1983        3102.10.10.00                      0                     1
# 1984        3102.10.10.00                      0                     1
# 1985        3102.10.10.00                      0                     1
# 1986        3102.10.10.00                      0                     1
#
#                                    DESCRIPCION POSICION  \
# 0     Con un porcentaje de nitrógeno superior o igua...
# 1     Con un porcentaje de nitrógeno superior o igua...
# 2     Con un porcentaje de nitrógeno superior o igua...
# 3     Con un porcentaje de nitrógeno superior o igua...
# 4     Con un porcentaje de nitrógeno superior o igua...
# ...                                                 ...
# 1982  Con un porcentaje de nitrógeno superior o igua...
# 1983  Con un porcentaje de nitrógeno superior o igua...
# 1984  Con un porcentaje de nitrógeno superior o igua...
# 1985  Con un porcentaje de nitrógeno superior o igua...
# 1986  Con un porcentaje de nitrógeno superior o igua...
#
#                                DESCRIPCION DEL DESPACHO      MARCA  \
# 0     UREA-COLOR BLANCO, NITROGENO 46.0% MIN GRANULO...        NaN
# 1                                                  UREA        NaN
# 2                                         UREA GRANULAR        NaN
# 3                    UREA PERLADA PARA USO FERTILIZANTE        NaN
# 4                                          UREA PERLADA        NaN
# ...                                                 ...        ...
# 1982                                         UREA, UREA  SIN MARCA
# 1983                                         UREA, UREA  SIN MARCA
# 1984                       UREA GRANULAR, UREA GRANULAR  SIN MARCA
# 1985                       UREA GRANULAR, UREA GRANULAR  SIN MARCA
# 1986                            UREA, PARA USO AGRICOLA    HEXAGON
#
#           MODELO          REFRENDO  ITEM         DAU FECHA DESPACHO  \
# 0            NaN    28200910000815     1  14279592.0     2009-01-06
# 1            NaN    82200910000803     1  14581329.0     2009-02-19
# 2            NaN    28200910018185     1  14623238.0     2009-03-06
# 3            NaN    82200910001064     1  14624789.0     2009-03-06
# 4            NaN    82200910001123     1  14633955.0     2009-03-11
# ...          ...               ...   ...         ...            ...
# 1982  SIN MODELO  2820241002997434     1         NaN     2024-12-16
# 1983  SIN MODELO  2820241002997434     2         NaN     2024-12-16
# 1984   PA38M2000  2820241003034107     1         NaN     2024-12-19
# 1985   PA38M2000  2820241003034107     2         NaN     2024-12-19
# 1986  SIN MODELO  2820241003038095     1         NaN     2024-12-19
#
#      FECHA EMBARQUE FECHA LLEGADA FECHA LIQUIDACION  FECHA PAGO  \
# 0        2008-10-27    2008-12-13        0000-00-00  0000-00-00
# 1        2009-02-18    2009-02-20        0000-00-00  0000-00-00
# 2        2009-03-02    2009-03-10        0000-00-00  0000-00-00
# 3        2009-03-04    2009-03-09        0000-00-00  0000-00-00
# 4        2009-03-10    2009-03-11        0000-00-00  0000-00-00
# ...             ...           ...               ...         ...
# 1982     2024-12-02    2024-12-23        2024-12-16  2024-12-17
# 1983     2024-12-02    2024-12-23        2024-12-16  2024-12-17
# 1984     2024-12-02    2024-12-23        2024-12-19  2024-12-19
# 1985     2024-12-02    2024-12-23        2024-12-19  2024-12-19
# 1986     2024-12-02    2024-12-23        2024-12-19  2024-12-19
#
#      FECHA SALIDA ALMACEN                REGIMEN NUMERO MANIFIESTO  \
# 0              0000-00-00  IMPORTACION A CONSUMO               NaN
# 1              0000-00-00  IMPORTACION A CONSUMO               NaN
# 2              0000-00-00  IMPORTACION A CONSUMO               NaN
# 3              0000-00-00  IMPORTACION A CONSUMO               NaN
# 4              0000-00-00  IMPORTACION A CONSUMO               NaN
# ...                   ...                    ...               ...
# 1982           0000-00-00  IMPORTACION A CONSUMO               NaN
# 1983           0000-00-00  IMPORTACION A CONSUMO               NaN
# 1984           0000-00-00  IMPORTACION A CONSUMO               NaN
# 1985           0000-00-00  IMPORTACION A CONSUMO               NaN
# 1986           2024-12-26  IMPORTACION A CONSUMO               NaN
#
#            MANIFIESTO CODIGO DOCUMENTO TRANSPORTE DOCUMENTO TRANSPORTE  \
# 0                1851                         NaN         MSCUVN989404
# 1                 810                         NaN   PE-0192-04-2009020
# 2                 467                         NaN                    1
# 3                1118                         NaN             028-2009
# 4                1197                         NaN      PE0192042009033
# ...               ...                         ...                  ...
# 1982  CEC202477870199     CEC20247787019900020000                EC-01
# 1983  CEC202477870199     CEC20247787019900020000                EC-01
# 1984  CEC202477870199     CEC20247787019900010000                    1
# 1985  CEC202477870199     CEC20247787019900010000                    1
# 1986  CEC202477870199     CEC20247787019900040000                EC-03
#
#                   ADUANA          PAIS ORIGEN     PAIS PROCEDENCIA  \
# 0     GUAYAQUIL MARITIMO                CHINA             VIET NAM
# 1             HUAQUILLAS   RUSSIAN FEDERATION                 PERU
# 2     GUAYAQUIL MARITIMO            VENEZUELA            VENEZUELA
# 3             HUAQUILLAS                 PERU                 PERU
# 4             HUAQUILLAS   RUSSIAN FEDERATION                 PERU
# ...                  ...                  ...                  ...
# 1982  GUAYAQUIL MARITIMO  TRINIDAD AND TOBAGO  TRINIDAD AND TOBAGO
# 1983  GUAYAQUIL MARITIMO  TRINIDAD AND TOBAGO  TRINIDAD AND TOBAGO
# 1984  GUAYAQUIL MARITIMO  TRINIDAD AND TOBAGO  TRINIDAD AND TOBAGO
# 1985  GUAYAQUIL MARITIMO  TRINIDAD AND TOBAGO  TRINIDAD AND TOBAGO
# 1986  GUAYAQUIL MARITIMO  TRINIDAD AND TOBAGO  TRINIDAD AND TOBAGO
#
#             PAIS EMBARQUE           PUERTO EMBARQUE VIA TRANSPORTE  \
# 0                VIET NAM    VNSGN-HO CHI MINH CITY       MARITIMO
# 1                    PERU               PEPAI-PAITA      CARRETERA
# 2               VENEZUELA  ZZZZZ-PUERTO DESCONOCIDO       MARITIMO
# 3                    PERU               PEPAI-PAITA      CARRETERA
# 4                    PERU               PEPAI-PAITA      CARRETERA
# ...                   ...                       ...            ...
# 1982  TRINIDAD AND TOBAGO         TTPTS-POINT LISAS       MARITIMO
# 1983  TRINIDAD AND TOBAGO         TTPTS-POINT LISAS       MARITIMO
# 1984  TRINIDAD AND TOBAGO         TTPTS-POINT LISAS       MARITIMO
# 1985  TRINIDAD AND TOBAGO         TTPTS-POINT LISAS       MARITIMO
# 1986  TRINIDAD AND TOBAGO         TTPTS-POINT LISAS       MARITIMO
#
#       CONTENEDORES DEPOSITO       FOB U$S   FLETE U$S SEGURO U$S  \
# 0              0.0      NaN    359,550.25   76,110.00   1,157.71
# 1              0.0      NaN     75,664.81    6,800.00     241.26
# 2              0.0      NaN  5,781,583.00  748,095.50  17,682.18
# 3              0.0      NaN     76,244.80    4,800.00     243.45
# 4              0.0      NaN     76,144.81    6,400.00     243.45
# ...            ...      ...           ...         ...        ...
# 1982           0.0      NaN  1,062,900.00         0.0  10,629.00
# 1983           0.0      NaN     13,909.11         0.0       0.01
# 1984           0.0      NaN    780,340.00         0.0   7,803.40
# 1985           0.0      NaN     10,211.46         0.0     102.11
# 1986           0.0      NaN    747,708.12         0.0   4,300.29
#
#            CIF U$S        FACTURA VALOR FACTURA U$S BASE IMPONIBLE U$S  \
# 0       436,817.97            NaN               0.0                0.0
# 1        82,706.07            NaN               0.0                0.0
# 2     6,547,360.50            NaN               0.0                0.0
# 3        81,288.25            NaN               0.0                0.0
# 4        82,788.26            NaN               0.0                0.0
# ...            ...            ...               ...                ...
# 1982  1,073,529.00      FG1-01097      1,076,809.12       1,208,229.00
# 1983     13,909.12      FG1-01097      1,076,809.12          13,909.14
# 1984    788,143.38  STL0110110448        790,551.44         885,229.38
# 1985     10,313.57  STL0110110448        790,551.44          10,313.59
# 1986    752,008.44   2410511-0412        747,708.12         840,653.44
#
#            KGS NETO      KGS BRUTO      UNIDADES      TIPO UNIDAD  \
# 0        575,000.00     576,725.00    575,000.00              NaN
# 1        240,000.00     240,400.00        240.00              NaN
# 2     20,648,510.00  20,648,510.00     20,648.51              NaN
# 3        240,000.00     240,400.00    240,000.00              NaN
# 4        240,000.00     240,400.00    240,000.00              NaN
# ...             ...            ...           ...              ...
# 1982   3,000,000.00            0.0  3,000,000.00  KILOGRAMO BRUTO
# 1983      39,258.00            0.0     39,258.00  KILOGRAMO BRUTO
# 1984   2,200,000.00            0.0  2,200,000.00  KILOGRAMO BRUTO
# 1985      28,789.00            0.0     28,789.00  KILOGRAMO BRUTO
# 1986   2,026,172.00            0.0  2,026,172.00  KILOGRAMO BRUTO
#
#       PRECIO UNITARIO U$S CANTIDAD COMERCIAL UNIDAD COMERCIAL  \
# 0                    0.63                0.0              NaN
# 1                  315.27                0.0              NaN
# 2                  280.00                0.0              NaN
# 3                    0.32                0.0              NaN
# 4                    0.32                0.0              NaN
# ...                   ...                ...              ...
# 1982                 0.35           3,000.00               TM
# 1983                 0.35              39.26               TM
# 1984                 0.35           2,200.00               TM
# 1985                 0.35              28.79               TM
# 1986                 0.37           2,026.17               TM
#
#      PRECIO UNITARIO COMERCIAL U$S TIPO UNIDAD NOMENCLADOR  ADVAL MONEDA  \
# 0                              0.0           kg, Kilogramo    0.0    DOL
# 1                              0.0           kg, Kilogramo    0.0    DOL
# 2                              0.0           kg, Kilogramo    0.0    DOL
# 3                              0.0           kg, Kilogramo    0.0    DOL
# 4                              0.0           kg, Kilogramo    0.0    DOL
# ...                            ...                     ...    ...    ...
# 1982                         354.3           kg, Kilogramo    0.0    DOL
# 1983                         354.3           kg, Kilogramo    0.0    DOL
# 1984                         354.7           kg, Kilogramo    0.0    DOL
# 1985                         354.7           kg, Kilogramo    0.0    DOL
# 1986                        369.02           kg, Kilogramo    0.0    DOL
#
#                 EMBARCADOR INCOTERM  \
# 0                 KEYTRADE      NaN
# 1      ADM ANDINA PERU SRL      NaN
# 2     IPSL INTERNATIONAL P      NaN
# 3     ADM ANDINA PERU S.R.      NaN
# 4      ADM ANDINA PERU SRL      NaN
# ...                    ...      ...
# 1982         INCOFE S.A.S.      CIF
# 1983         INCOFE S.A.S.      CIF
# 1984  YARA SWITZERLAND LTD      CIF
# 1985  YARA SWITZERLAND LTD      CIF
# 1986    HEXAGON TRADING AG      CFR
#
#                                       CODIGO LIBERACION ESTADO MERCADERIA  \
# 0     IVA 0 semillas ,bulbos,plantas,esquejes,raices...             NUEVO
# 1     IVA 0 semillas ,bulbos,plantas,esquejes,raices...             NUEVO
# 2     Tarifa 0 IVA, Sector público, cuando concurran...             NUEVO
# 3     IVA 0 semillas ,bulbos,plantas,esquejes,raices...             NUEVO
# 4     IVA 0 semillas ,bulbos,plantas,esquejes,raices...             NUEVO
# ...                                                 ...               ...
# 1982  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 1983  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 1984  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 1985  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 1986  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
#
#       CLASE MERCADERIA     PAIS DESTINO TOTAL FOB U$S TOTAL FLETE U$S  \
# 0                  NaN  NO ESPECIFICADO    359,550.25       76,110.00
# 1                  NaN  NO ESPECIFICADO     75,664.81        6,800.00
# 2                  NaN  NO ESPECIFICADO  5,781,583.00      748,095.50
# 3                  NaN  NO ESPECIFICADO     76,244.80        4,800.00
# 4                  NaN  NO ESPECIFICADO     76,144.81        6,400.00
# ...                ...              ...           ...             ...
# 1982               NaN          ECUADOR  1,076,809.12             0.0
# 1983               NaN          ECUADOR           NaN             NaN
# 1984               NaN          ECUADOR    790,551.44             0.0
# 1985               NaN          ECUADOR           NaN             NaN
# 1986               NaN          ECUADOR    747,708.12             0.0
#
#      TOTAL SEGURO U$S TOTAL CIF U$S TOTAL KGS NETO TOTAL KGS BRUTO  \
# 0            1,157.71    436,817.97     575,000.00      576,725.00
# 1              241.26     82,706.07     240,000.00      240,400.00
# 2           17,682.18  6,547,360.50  20,648,510.00   20,648,510.00
# 3              243.45     81,288.25     240,000.00      240,400.00
# 4              243.45     82,788.26     240,000.00      240,400.00
# ...               ...           ...            ...             ...
# 1982        10,629.01  1,087,438.12   3,039,258.00             0.0
# 1983              NaN           NaN            NaN             NaN
# 1984         7,905.51    798,456.94   2,228,789.00             0.0
# 1985              NaN           NaN            NaN             NaN
# 1986         4,300.29    752,008.44   2,026,172.00             0.0
#
#      TOTAL BASE IMPONIBLE TOTAL CANTIDAD BULTOS TOTAL AJUSTES  \
# 0                     0.0             11,500.00           0.0
# 1                     0.0              4,800.00           0.0
# 2                     0.0                  1.00           0.0
# 3                     0.0              4,800.00           0.0
# 4                     0.0              4,800.00           0.0
# ...                   ...                   ...           ...
# 1982         1,222,138.12                   0.0           0.0
# 1983                  NaN                   NaN           NaN
# 1984           895,542.94                   0.0           0.0
# 1985                  NaN                   NaN           NaN
# 1986           840,653.44                   0.0           0.0
#
#      TOTAL OTROS AJUSTES                         CLASE VERIFICADOR  \
# 0                    0.0                         BOLSA      ADUANA
# 1                    0.0       SACO DE TEJIDO PLASTICO      ADUANA
# 2                    0.0  SIN ENVASAR O SIN EMPAQUETAR      ADUANA
# 3                    0.0                          SACO      ADUANA
# 4                    0.0       SACO DE TEJIDO PLASTICO      ADUANA
# ...                  ...                           ...         ...
# 1982                 0.0                           NaN         NaN
# 1983                 NaN                           NaN         NaN
# 1984                 0.0                           NaN         NaN
# 1985                 NaN                           NaN         NaN
# 1986                 0.0                           NaN         NaN
#
#                                        AGENTE AFIANZADO        NAVE  \
# 0           01902288: ILLINGWORTH GARCIA CRISTOBAL LUIS  MSC PARANA
# 1                  01903692: PRIETO VEGA LAURA MACLOVIA         NaN
# 2            01903476: PAREDES VINUEZA SEGUNDO BENJAMIN         NaN
# 3                01906284: NAVARRO RAMON ALBERTO DANILO         NaN
# 4                  01903692: PRIETO VEGA LAURA MACLOVIA         NaN
# ...                                                 ...         ...
# 1982  01902441: TORRES & TORRES AGENTES DE ADUANAS T...    SEAHORSE
# 1983  01902441: TORRES & TORRES AGENTES DE ADUANAS T...    SEAHORSE
# 1984  01902441: TORRES & TORRES AGENTES DE ADUANAS T...    SEAHORSE
# 1985  01902441: TORRES & TORRES AGENTES DE ADUANAS T...    SEAHORSE
# 1986                               01777833: CORADUANAS    SEAHORSE
#
#                                      AGENCIA TRANSPORTE  \
# 0                MEDITERRANEAN SHIPPING CO.ECUADOR C.A.
# 1                                     SERVIMODAL S.A.C.
# 2                                       INVESTAMAR S.A.
# 3                                SANTA ESPERANZA S.R.L.
# 4                                     SERVIMODAL S.A.C.
# ...                                                 ...
# 1982  02777787-REMAR REPRESENTACIONES MARITIMAS DEL ...
# 1983  02777787-REMAR REPRESENTACIONES MARITIMAS DEL ...
# 1984  02777787-REMAR REPRESENTACIONES MARITIMAS DEL ...
# 1985  02777787-REMAR REPRESENTACIONES MARITIMAS DEL ...
# 1986  02777787-REMAR REPRESENTACIONES MARITIMAS DEL ...
#
#                                      EMPRESA TRANSPORTE  \
# 0                                 MEDITERANEAN SHIPPING
# 1                                     SERVIMODAL S.A.C.
# 2                                    AGENCIA NO REGULAR
# 3                                SANTA ESPERANZA S.R.L.
# 4                                     SERVIMODAL S.A.C.
# ...                                                 ...
# 1982  02777787-REMAR REPRESENTACIONES MARITIMAS DEL ...
# 1983  02777787-REMAR REPRESENTACIONES MARITIMAS DEL ...
# 1984  02777787-REMAR REPRESENTACIONES MARITIMAS DEL ...
# 1985  02777787-REMAR REPRESENTACIONES MARITIMAS DEL ...
# 1986  02777787-REMAR REPRESENTACIONES MARITIMAS DEL ...
#
#                                      AFORADOR FECHA AFORO        TIPO AFORO  \
# 0                                         NaN  0000-00-00      AFORO FISICO
# 1                                         NaN  0000-00-00  AFORO DOCUMENTAL
# 2                                         NaN  0000-00-00  AFORO DOCUMENTAL
# 3                                         NaN  0000-00-00  AFORO DOCUMENTAL
# 4                                         NaN  0000-00-00  AFORO DOCUMENTAL
# ...                                       ...         ...               ...
# 1982  GEFARIAS-FARIAS VARGAS GENESIS ANDREINA  0000-00-00  AFORO DOCUMENTAL
# 1983  GEFARIAS-FARIAS VARGAS GENESIS ANDREINA  0000-00-00  AFORO DOCUMENTAL
# 1984                                      NaN  0000-00-00  AFORO AUTOMATICO
# 1985                                      NaN  0000-00-00  AFORO AUTOMATICO
# 1986                                      NaN  0000-00-00  AFORO AUTOMATICO
#
#                      ACTIVIDAD PRINCIPAL DEL IMPORTADOR  \
# 0                   VENTA AL POR MAYOR DE FERTILIZANTES
# 1            5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 2                                                   NaN
# 3            5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 4            5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# ...                                                 ...
# 1982                                         9993-OTROS
# 1983                                         9993-OTROS
# 1984  0140-ACTIVIDADES DE SERVICIOS AGRICOLAS Y GANA...
# 1985  0140-ACTIVIDADES DE SERVICIOS AGRICOLAS Y GANA...
# 1986         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
#
#                                DIRECCION DEL IMPORTADOR  \
# 0                           V.E. ESTRADA 114 Y BALSAMOS
# 1           PARA EL CAMPO VIA DURAN - TAMBO KM 9, DURAN
# 2                            107 ANTE Y AV 10 DE AGOSTO
# 3           PARA EL CAMPO VIA DURAN - TAMBO KM 9, DURAN
# 4           PARA EL CAMPO VIA DURAN - TAMBO KM 9, DURAN
# ...                                                 ...
# 1982  Sector Quitumbe, calle S31 y Quipu, conjunto A...
# 1983  Sector Quitumbe, calle S31 y Quipu, conjunto A...
# 1984            KM 1 5 SOLAR 120 Y LOS ARCOS EDIF LOS A
# 1985            KM 1 5 SOLAR 120 Y LOS ARCOS EDIF LOS A
# 1986                  AMAZONAS N35-43 Y JUAN PABLO SANZ
#
#      DIRECCION DEL CONSIGNATARIO CONSOLIDADORA
# 0                            NaN           NaN
# 1                            NaN           NaN
# 2                            NaN           NaN
# 3                            NaN           NaN
# 4                            NaN           NaN
# ...                          ...           ...
# 1982                         NaN           NaN
# 1983                         NaN           NaN
# 1984                         NaN           NaN
# 1985                         NaN           NaN
# 1986                         NaN           NaN
#
# [1987 rows x 81 columns]

# %% [markdown]
# Ahora, con una mascara escojo las columnas que me convienen.

# %%
data_total_2 = ['RAZON SOCIAL','FECHA EMBARQUE',
       'PAIS ORIGEN', 'VIA TRANSPORTE', 'PAIS DESTINO', 'FOB U$S', 'FLETE U$S', 'TOTAL KGS NETO']
data_total_raw_importaciones_urea = data_total_raw_importaciones_urea[data_total_2]

data_total_raw_importaciones_urea
# Out:
#                                           RAZON SOCIAL FECHA EMBARQUE  \
# 0                                         DELCORP S.A.     2008-10-27
# 1     DUPOCSA PROTECTORES QUIMICOS PARA EL CAMPO S. A.     2009-02-18
# 2                        BANCO NACIONAL DE FOMENTO BNF     2009-03-02
# 3     DUPOCSA PROTECTORES QUIMICOS PARA EL CAMPO S. A.     2009-03-04
# 4     DUPOCSA PROTECTORES QUIMICOS PARA EL CAMPO S. A.     2009-03-10
# ...                                                ...            ...
# 1982                                   PRECISAGRO S.A.     2024-12-02
# 1983                                   PRECISAGRO S.A.     2024-12-02
# 1984                               YARECUADOR CIA LTDA     2024-12-02
# 1985                               YARECUADOR CIA LTDA     2024-12-02
# 1986  QUIMICA INDUSTRIAL MONTALVO AGUILAR QUIMASA S.A.     2024-12-02
#
#               PAIS ORIGEN VIA TRANSPORTE     PAIS DESTINO       FOB U$S  \
# 0                   CHINA       MARITIMO  NO ESPECIFICADO    359,550.25
# 1      RUSSIAN FEDERATION      CARRETERA  NO ESPECIFICADO     75,664.81
# 2               VENEZUELA       MARITIMO  NO ESPECIFICADO  5,781,583.00
# 3                    PERU      CARRETERA  NO ESPECIFICADO     76,244.80
# 4      RUSSIAN FEDERATION      CARRETERA  NO ESPECIFICADO     76,144.81
# ...                   ...            ...              ...           ...
# 1982  TRINIDAD AND TOBAGO       MARITIMO          ECUADOR  1,062,900.00
# 1983  TRINIDAD AND TOBAGO       MARITIMO          ECUADOR     13,909.11
# 1984  TRINIDAD AND TOBAGO       MARITIMO          ECUADOR    780,340.00
# 1985  TRINIDAD AND TOBAGO       MARITIMO          ECUADOR     10,211.46
# 1986  TRINIDAD AND TOBAGO       MARITIMO          ECUADOR    747,708.12
#
#        FLETE U$S TOTAL KGS NETO
# 0      76,110.00     575,000.00
# 1       6,800.00     240,000.00
# 2     748,095.50  20,648,510.00
# 3       4,800.00     240,000.00
# 4       6,400.00     240,000.00
# ...          ...            ...
# 1982         0.0   3,039,258.00
# 1983         0.0            NaN
# 1984         0.0   2,228,789.00
# 1985         0.0            NaN
# 1986         0.0   2,026,172.00
#
# [1987 rows x 8 columns]

# %% [markdown]
# Ahora revisare, columna a columna, los valores unicos y los NaN.

# %%
# Empezamos por FECHA EMBARQUE

# %%
data_total_raw_importaciones_urea['FECHA EMBARQUE'].value_counts()
# Out:
# FECHA EMBARQUE
# 0000-00-00    187
# 2024-04-28     12
# 2024-10-15     11
# 2023-12-23     11
# 2021-12-30     10
#              ...
# 2016-04-25      1
# 2016-04-03      1
# 2016-04-06      1
# 2016-03-29      1
# 2016-12-17      1
# Name: count, Length: 962, dtype: int64

# %%
data_total_raw_importaciones_urea['FECHA EMBARQUE'].isna().sum()
# Out:
# np.int64(0)

# %%
# PAIS ORIGEN

# %%
data_total_raw_importaciones_urea['PAIS ORIGEN'].value_counts()
# Out:
# PAIS ORIGEN
# RUSSIAN FEDERATION      1233
# NO ESPECIFICADO          243
# CHINA                    212
# GERMANY                   41
# PERU                      39
# UNITED STATES             34
# VENEZUELA                 27
# UKRAINE                   24
# BELARUS                   20
# FINLAND                   17
# MALAYSIA                  13
# INDONESIA                 12
# COLOMBIA                  12
# FRANCE                     9
# LITHUANIA                  9
# TRINIDAD AND TOBAGO        7
# ESTONIA                    7
# EGYPT                      7
# LATVIA                     5
# PAISES BAJOS               3
# INDIA                      2
# SPAIN                      2
# BELGIUM                    2
# NIGERIA                    2
# UNITED ARAB EMIRATES       1
# POLAND                     1
# NEW ZEALAND                1
# SWITZERLAND                1
# ALGERIA                    1
# Name: count, dtype: int64

# %%
data_total_raw_importaciones_urea['PAIS ORIGEN'].isna().sum()
# Out:
# np.int64(0)

# %%
# FOB U$S

# %%
data_total_raw_importaciones_urea['FOB U$S'].value_counts()
# Out:
# FOB U$S
# 46,950.00     12
# 14,518.06      6
# 20,480.00      5
# 26,400.00      5
# 29,030.00      5
#               ..
# 13,845.00      1
# 167,361.98     1
# 130,100.00     1
# 216,870.20     1
# 747,708.12     1
# Name: count, Length: 1803, dtype: int64

# %%
data_total_raw_importaciones_urea['FOB U$S'].isna().sum()
# Out:
# np.int64(0)

# %%
(data_total_raw_importaciones_urea['FOB U$S'] == 0).sum()
# Out:
# np.int64(0)

# %%
# FLETE U$S

# %%
data_total_raw_importaciones_urea['FLETE U$S'].isna().sum()
# Out:
# np.int64(0)

# %%
(data_total_raw_importaciones_urea['FLETE U$S'] == 0).sum()
# Out:
# np.int64(122)

# %%
# TOTAL KGS NETO

# %%
data_total_raw_importaciones_urea['TOTAL KGS NETO'].value_counts()
# Out:
# TOTAL KGS NETO
# 32,000.00       56
# 3,300,000.00    45
# 1,100,000.00    45
# 2,200,000.00    40
# 0.00            40
#                 ..
# 432,000.00       1
# 1,026,000.00     1
# 965,700.00       1
# 978.00           1
# 2,026,172.00     1
# Name: count, Length: 837, dtype: int64

# %%
data_total_raw_importaciones_urea['TOTAL KGS NETO'].isna().sum()
# Out:
# np.int64(205)

# %% [markdown]
# Me he dado cuenta que:
#
# -En FLETE tengo unos 0.0 y 0.00
#
# -En TOTAL KGS NETO tengo Unos 0.00 y unos NaN
#
# -En PAIS DE ORIGEN, tengo paises no especificados.

# %%
data_total_raw_importaciones_urea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1987 entries, 0 to 1986
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RAZON SOCIAL    1987 non-null   object
#  1   FECHA EMBARQUE  1987 non-null   object
#  2   PAIS ORIGEN     1987 non-null   object
#  3   VIA TRANSPORTE  1987 non-null   object
#  4   PAIS DESTINO    1957 non-null   object
#  5   FOB U$S         1987 non-null   object
#  6   FLETE U$S       1987 non-null   object
#  7   TOTAL KGS NETO  1782 non-null   object
# dtypes: object(8)
# memory usage: 124.3+ KB

# %% [markdown]
# Empiezo por rellenar los NaN y 0 de las columnas FLETE y KGS. Me doy cuenta que estas columnas estan como objetos. Tengo que pasarlas a int para poder modificarlas. Primero extraigo las comas y cualquier signo de dolar (porsiacaso).

# %%
# Defino las columnas a limpiar
columns_to_clean = ['FOB U$S', 'FLETE U$S', 'TOTAL KGS NETO']

# Convierto los valores
for column in columns_to_clean:
    data_total_raw_importaciones_urea.loc[:, column] = (
        data_total_raw_importaciones_urea[column]
        .str.replace('$', '', regex=False)  
        .str.replace(',', '', regex=False) 
        .str.strip()                       
    )

# %% [markdown]
# Ahora cambio las filas FILETE U$S, FOB U$S Y TOTAL KGS NETO a numerico.

# %%
data_total_raw_importaciones_urea[['FLETE U$S', 'FOB U$S', 'TOTAL KGS NETO']] = data_total_raw_importaciones_urea[['FLETE U$S', 'FOB U$S', 'TOTAL KGS NETO']].apply(pd.to_numeric, errors='coerce')
# Out:
# /var/folders/9d/njcmv3bs67bgg_6p6s5pyjsw0000gn/T/ipykernel_3028/432266307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total_raw_importaciones_urea[['FLETE U$S', 'FOB U$S', 'TOTAL KGS NETO']] = data_total_raw_importaciones_urea[['FLETE U$S', 'FOB U$S', 'TOTAL KGS NETO']].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# Siendo el comentario, verifico que las columnas se hayan cambiado a numerico.

# %%
data_total_raw_importaciones_urea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1987 entries, 0 to 1986
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RAZON SOCIAL    1987 non-null   object
#  1   FECHA EMBARQUE  1987 non-null   object
#  2   PAIS ORIGEN     1987 non-null   object
#  3   VIA TRANSPORTE  1987 non-null   object
#  4   PAIS DESTINO    1957 non-null   object
#  5   FOB U$S         1987 non-null   float64
#  6   FLETE U$S       1862 non-null   float64
#  7   TOTAL KGS NETO  1782 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 124.3+ KB

# %% [markdown]
# Ahora reemplazo los NaN y 0 por el MEAN de su razon social especifica.

# %%
columns = ['FLETE U$S', 'TOTAL KGS NETO']

for col in columns:
    means_by_razon = data_total_raw_importaciones_urea[data_total_raw_importaciones_urea[col] > 0].groupby('RAZON SOCIAL')[col].mean()
    
    data_total_raw_importaciones_urea.loc[:, col] = data_total_raw_importaciones_urea[col].fillna(data_total_raw_importaciones_urea['RAZON SOCIAL'].map(means_by_razon))
    
    # Ahora, reemplazo los ceros con el promedio por RAZON SOCIAL
    data_total_raw_importaciones_urea.loc[data_total_raw_importaciones_urea[col] == 0, col] = (data_total_raw_importaciones_urea.loc[data_total_raw_importaciones_urea[col] == 0, 'RAZON SOCIAL'].map(means_by_razon))

# Por dudas, erifico
for col in columns:
    print(f"\n{col}:")
    print(f"NaN: {data_total_raw_importaciones_urea[col].isna().sum()}")
    print(f"0: {(data_total_raw_importaciones_urea[col] == 0).sum()}")
# Out:
# FLETE U$S:
# NaN: 0
# 0: 0
#
# TOTAL KGS NETO:
# NaN: 0
# 0: 0

# %% [markdown]
# Con los que me sale como pais de origen no especificado, siendo que es un valor representativo, voy a distribuir estos valores entre los 6 paises principales.

# %%
data_total_raw_importaciones_urea[data_total_raw_importaciones_urea['PAIS ORIGEN'] == 'NO ESPECIFICADO']
# Out:
#                                           RAZON SOCIAL FECHA EMBARQUE  \
# 290   QUIMICA INDUSTRIAL MONTALVO AGUILAR QUIMASA S.A.     2012-11-30
# 291          IMPORTADORA INDUSTRIAL AGRICOLA DEL MONTE     2012-12-08
# 292                                SOLVESA ECUADOR S.A     2012-12-16
# 293         FERTILIZANTES DEL PACIFICO FERPACIFIC S.A.     2012-12-30
# 294                                       DELCORP S.A.     2012-12-30
# ..                                                 ...            ...
# 543                                       DELCORP S.A.     2014-08-13
# 544  INTERAMERICANA DE PRODUCTOS QUIMICOS DEL ECUAD...     2014-08-18
# 545  INTERAMERICANA DE PRODUCTOS QUIMICOS DEL ECUAD...     2014-08-18
# 546                                       DELCORP S.A.     2014-08-17
# 547                                       DELCORP S.A.     2014-07-31
#
#          PAIS ORIGEN VIA TRANSPORTE PAIS DESTINO    FOB U$S  FLETE U$S  \
# 290  NO ESPECIFICADO       MARITIMO      ECUADOR  222794.00   33000.00
# 291  NO ESPECIFICADO       MARITIMO      ECUADOR  153291.84   12885.00
# 292  NO ESPECIFICADO       MARITIMO      ECUADOR  282403.62   18502.00
# 293  NO ESPECIFICADO       MARITIMO      ECUADOR  133980.00   20880.00
# 294  NO ESPECIFICADO       MARITIMO      ECUADOR  870812.12  109672.75
# ..               ...            ...          ...        ...        ...
# 543  NO ESPECIFICADO       MARITIMO      ECUADOR   98761.00   26000.00
# 544  NO ESPECIFICADO       MARITIMO      ECUADOR  160398.00   33516.00
# 545  NO ESPECIFICADO       MARITIMO      ECUADOR  369869.50   71294.08
# 546  NO ESPECIFICADO       MARITIMO      ECUADOR   45582.00   13310.00
# 547  NO ESPECIFICADO       MARITIMO      ECUADOR   49776.65    4985.48
#
#      TOTAL KGS NETO
# 290        550000.0
# 291        312000.0
# 292        637480.0
# 293        348000.0
# 294       2099000.0
# ..              ...
# 543        273000.0
# 544        479864.0
# 545       1096832.0
# 546        126000.0
# 547         55000.0
#
# [243 rows x 8 columns]

# %%
no_spec_mask = data_total_raw_importaciones_urea['PAIS ORIGEN'] == 'NO ESPECIFICADO'
total_no_spec = no_spec_mask.sum()

# Escojo los paises entre los que distibuire
target_countries = ['RUSSIAN FEDERATION', 'CHINA', 'UNITED STATES', 'PERU', 'MALAYSIA', 'INDONESIA']

# Divido entre los 6
records_per_country = total_no_spec // 6

# Hacemos las asignasiones random
random_assignments = np.repeat(target_countries, records_per_country)

# Cualquiera que quede lo agregamos random
remainder = total_no_spec - len(random_assignments)
if remainder > 0:
    random_assignments = np.concatenate([
        random_assignments,
        np.random.choice(target_countries, remainder)
    ])

# Hacemos shuffle a los assigments
np.random.shuffle(random_assignments)

# Reemplazo los NO ESPECIFICADO con random
data_total_raw_importaciones_urea.loc[no_spec_mask, 'PAIS ORIGEN'] = random_assignments

# Verificamos distribucion
print("Distribucion:")
for country in target_countries:
    count = len(data_total_raw_importaciones_urea[data_total_raw_importaciones_urea['PAIS ORIGEN'] == country])
    print(f"{country}: {count}")

print("'NO ESPECIFICADO':", 
      len(data_total_raw_importaciones_urea[data_total_raw_importaciones_urea['PAIS ORIGEN'] == 'NO ESPECIFICADO']))
# Out:
# Distribucion:
# RUSSIAN FEDERATION: 1273
# CHINA: 252
# UNITED STATES: 76
# PERU: 79
# MALAYSIA: 54
# INDONESIA: 52
# 'NO ESPECIFICADO': 0

# %% [markdown]
# Reviso el valor de las filas con fechas nulas y si no es significativo, las borro

# %%
len(data_total_raw_importaciones_urea[data_total_raw_importaciones_urea['FECHA EMBARQUE'] == '0000-00-00'])
# Out:
# 187

# %%
data_total_raw_importaciones_urea = data_total_raw_importaciones_urea[data_total_raw_importaciones_urea['FECHA EMBARQUE'] != '0000-00-00']

# %% [markdown]
# Borro las razones sociales

# %%
data_total_3 = ['FECHA EMBARQUE',
       'PAIS ORIGEN', 'FOB U$S', 'TOTAL KGS NETO']
resultado_data_total_importaciones_urea = data_total_raw_importaciones_urea[data_total_3]

resultado_data_total_importaciones_urea
# Out:
#      FECHA EMBARQUE          PAIS ORIGEN     FOB U$S  TOTAL KGS NETO
# 0        2008-10-27                CHINA   359550.25        575000.0
# 1        2009-02-18   RUSSIAN FEDERATION    75664.81        240000.0
# 2        2009-03-02            VENEZUELA  5781583.00      20648510.0
# 3        2009-03-04                 PERU    76244.80        240000.0
# 4        2009-03-10   RUSSIAN FEDERATION    76144.81        240000.0
# ...             ...                  ...         ...             ...
# 1982     2024-12-02  TRINIDAD AND TOBAGO  1062900.00       3039258.0
# 1983     2024-12-02  TRINIDAD AND TOBAGO    13909.11       2764157.8
# 1984     2024-12-02  TRINIDAD AND TOBAGO   780340.00       2228789.0
# 1985     2024-12-02  TRINIDAD AND TOBAGO    10211.46       2782829.8
# 1986     2024-12-02  TRINIDAD AND TOBAGO   747708.12       2026172.0
#
# [1800 rows x 4 columns]

# %% [markdown]
# Sacamos el total de cuanto ha importado cada pais.

# %%
resumen_por_pais = resultado_data_total_importaciones_urea.groupby('PAIS ORIGEN').agg({'FOB U$S': 'sum','TOTAL KGS NETO': 'sum'}).reset_index()

# Renombrar columnas para el pie chart que crearemos
resumen_por_pais.columns = ['País', 'FOB Total', 'KGS NETO Total']

resumen_por_pais = resumen_por_pais.sort_values('FOB Total', ascending=False)

resumen_por_pais
# Out:
#                     País     FOB Total  KGS NETO Total
# 20    RUSSIAN FEDERATION  6.111654e+08    2.005964e+09
# 27             VENEZUELA  1.310475e+08    3.626484e+08
# 3                  CHINA  1.193653e+08    4.447610e+08
# 24               UKRAINE  3.965944e+07    1.107855e+08
# 11             INDONESIA  2.444779e+07    7.143645e+07
# 18                  PERU  2.426616e+07    7.014828e+07
# 26         UNITED STATES  2.156188e+07    5.953818e+07
# 1                BELARUS  1.964173e+07    8.242050e+07
# 14              MALAYSIA  1.902323e+07    5.752314e+07
# 13             LITHUANIA  8.477337e+06    4.563021e+07
# 7                FINLAND  6.667015e+06    2.230346e+07
# 12                LATVIA  4.529588e+06    1.866508e+07
# 6                ESTONIA  4.247441e+06    1.338396e+07
# 23   TRINIDAD AND TOBAGO  3.629594e+06    1.554121e+07
# 5                  EGYPT  3.551378e+06    1.548214e+07
# 16               NIGERIA  2.503542e+06    8.967470e+06
# 2                BELGIUM  1.387137e+06    5.529000e+06
# 25  UNITED ARAB EMIRATES  5.247746e+05    1.000000e+06
# 10                 INDIA  3.075496e+05    3.138479e+05
# 15           NEW ZEALAND  2.851594e+05    9.450000e+05
# 0                ALGERIA  2.290410e+05    9.000000e+05
# 22           SWITZERLAND  1.203056e+05    4.930000e+05
# 9                GERMANY  1.032956e+05    3.609284e+05
# 17          PAISES BAJOS  3.177202e+04    7.379200e+04
# 8                 FRANCE  2.026416e+04    9.917740e+04
# 19                POLAND  9.930000e+03    3.000000e+04
# 4               COLOMBIA  7.929350e+03    7.730510e+04
# 21                 SPAIN  1.558800e+02    2.546229e+04

# %%
resumen_por_pais.to_csv('Data_2/resumen_por_pais.csv', index=False)

# %% [markdown]
# Cambio el nombre de la columna de fecha para que pueda concidir con los otros Data Sets

# %%
resultado_data_total_importaciones_urea = resultado_data_total_importaciones_urea.rename(columns={'FECHA EMBARQUE': 'FECHA'})

# %% [markdown]
# Ahora guardo el csv

# %%
resultado_data_total_importaciones_urea.to_csv('Data_2/resultado_por_dia_total_urea.csv')

# %% [markdown]
# Ahora quiero saber los valores por mes/año.

# %%
resultado_data_total_importaciones_urea
# Out:
#            FECHA          PAIS ORIGEN     FOB U$S  TOTAL KGS NETO
# 0     2008-10-27                CHINA   359550.25        575000.0
# 1     2009-02-18   RUSSIAN FEDERATION    75664.81        240000.0
# 2     2009-03-02            VENEZUELA  5781583.00      20648510.0
# 3     2009-03-04                 PERU    76244.80        240000.0
# 4     2009-03-10   RUSSIAN FEDERATION    76144.81        240000.0
# ...          ...                  ...         ...             ...
# 1982  2024-12-02  TRINIDAD AND TOBAGO  1062900.00       3039258.0
# 1983  2024-12-02  TRINIDAD AND TOBAGO    13909.11       2764157.8
# 1984  2024-12-02  TRINIDAD AND TOBAGO   780340.00       2228789.0
# 1985  2024-12-02  TRINIDAD AND TOBAGO    10211.46       2782829.8
# 1986  2024-12-02  TRINIDAD AND TOBAGO   747708.12       2026172.0
#
# [1800 rows x 4 columns]

# %% [markdown]
# Borramos las columnas que no son necesarias

# %%
data_total_4 = ['FECHA', 'FOB U$S', 'TOTAL KGS NETO']
importaciones_urea_simplificadas = resultado_data_total_importaciones_urea[data_total_4]

importaciones_urea_simplificadas
# Out:
#            FECHA     FOB U$S  TOTAL KGS NETO
# 0     2008-10-27   359550.25        575000.0
# 1     2009-02-18    75664.81        240000.0
# 2     2009-03-02  5781583.00      20648510.0
# 3     2009-03-04    76244.80        240000.0
# 4     2009-03-10    76144.81        240000.0
# ...          ...         ...             ...
# 1982  2024-12-02  1062900.00       3039258.0
# 1983  2024-12-02    13909.11       2764157.8
# 1984  2024-12-02   780340.00       2228789.0
# 1985  2024-12-02    10211.46       2782829.8
# 1986  2024-12-02   747708.12       2026172.0
#
# [1800 rows x 3 columns]

# %% [markdown]
# Ahora si atacamos

# %%
# Hacemos que la fecha sea datetime
importaciones_urea_simplificadas['FECHA'] = pd.to_datetime(importaciones_urea_simplificadas['FECHA'], format="%Y-%m-%d")   

# Extraemos año y mes
importaciones_urea_simplificadas['Año'] = importaciones_urea_simplificadas['FECHA'].dt.year
importaciones_urea_simplificadas['Mes'] = importaciones_urea_simplificadas['FECHA'].dt.month

# Creamos DataFrame para FOB U$S por mes y año
fob_por_mes = importaciones_urea_simplificadas.groupby(['Año', 'Mes'])['FOB U$S'].sum().reset_index()
fob_por_mes.columns = ['Año', 'Mes', 'FOB U$S Total']
fob_por_mes = fob_por_mes.sort_values(['Año', 'Mes'])

# Creamos DataFrame para TOTAL KGS NETO por mes y año
kgs_por_mes = importaciones_urea_simplificadas.groupby(['Año', 'Mes'])['TOTAL KGS NETO'].sum().reset_index()
kgs_por_mes.columns = ['Año', 'Mes', 'TOTAL KGS NETO']
kgs_por_mes = kgs_por_mes.sort_values(['Año', 'Mes'])
# Out:
# /var/folders/9d/njcmv3bs67bgg_6p6s5pyjsw0000gn/T/ipykernel_3028/1096727660.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   importaciones_urea_simplificadas['FECHA'] = pd.to_datetime(importaciones_urea_simplificadas['FECHA'], format="%Y-%m-%d")

# %%
fob_por_mes
# Out:
#       Año  Mes  FOB U$S Total
# 0    2008   10      359550.25
# 1    2009    2       75664.81
# 2    2009    3    12169329.36
# 3    2009    4     4232816.50
# 4    2009    5     3604214.75
# ..    ...  ...            ...
# 166  2024    8      511807.44
# 167  2024    9     7894563.62
# 168  2024   10    10755710.00
# 169  2024   11     3101462.42
# 170  2024   12     3629593.69
#
# [171 rows x 3 columns]

# %%
fob_por_mes.to_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data_2/fob_kgs/fob_por_mes.csv')

# %%
fob_por_mes_ordenado = fob_por_mes.sort_values('FOB U$S Total', ascending=False)

# %%
fob_por_mes_ordenado.to_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data_2/fob_kgs/fob_por_mes_ordenado.csv')

# %%
kgs_por_mes
# Out:
#       Año  Mes  TOTAL KGS NETO
# 0    2008   10    5.750000e+05
# 1    2009    2    2.400000e+05
# 2    2009    3    4.270699e+07
# 3    2009    4    1.650221e+07
# 4    2009    5    1.686980e+07
# ..    ...  ...             ...
# 166  2024    8    1.598000e+06
# 167  2024    9    2.621726e+07
# 168  2024   10    3.053837e+07
# 169  2024   11    1.086499e+07
# 170  2024   12    1.554121e+07
#
# [171 rows x 3 columns]

# %%
kgs_por_mes.to_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data_2/fob_kgs/kgs_por_mes.csv')

# %%
kgs_por_mes_ordenado = kgs_por_mes.sort_values('TOTAL KGS NETO', ascending=False)
kgs_por_mes_ordenado
# Out:
#       Año  Mes  TOTAL KGS NETO
# 77   2016    4    7.359422e+07
# 96   2017   11    7.030546e+07
# 69   2014   11    6.888001e+07
# 158  2023   12    6.571547e+07
# 57   2013   11    5.940054e+07
# ..    ...  ...             ...
# 18   2010    8    4.000000e+04
# 52   2013    6    3.393000e+04
# 71   2015    1    2.970000e+04
# 143  2022    8    1.286700e+03
# 62   2014    4    2.756700e+02
#
# [171 rows x 3 columns]

# %%
kgs_por_mes_ordenado.to_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data_2/fob_kgs/kgs_por_mes_ordenado.csv')

# %%
# Uno los dos data frames usando año y mes como clave
fob_kgs_por_mes = pd.merge(
    fob_por_mes,         
    kgs_por_mes,         
    on=['Año', 'Mes'],   
    how='inner'          
)

# %%
fob_kgs_por_mes
# Out:
#       Año  Mes  FOB U$S Total  TOTAL KGS NETO
# 0    2008   10      359550.25    5.750000e+05
# 1    2009    2       75664.81    2.400000e+05
# 2    2009    3    12169329.36    4.270699e+07
# 3    2009    4     4232816.50    1.650221e+07
# 4    2009    5     3604214.75    1.686980e+07
# ..    ...  ...            ...             ...
# 166  2024    8      511807.44    1.598000e+06
# 167  2024    9     7894563.62    2.621726e+07
# 168  2024   10    10755710.00    3.053837e+07
# 169  2024   11     3101462.42    1.086499e+07
# 170  2024   12     3629593.69    1.554121e+07
#
# [171 rows x 4 columns]

# %%
fob_kgs_por_mes.to_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data_2/fob_kgs/fob_kgs_por_mes.csv')

# %%
# Uno los ordenados
fob_kgs_por_mes_ordenado = pd.merge(
    fob_por_mes_ordenado,        
    kgs_por_mes_ordenado,        
    on=['Año', 'Mes'],   
    how='inner'          
)

# %%
fob_kgs_por_mes_ordenado
# Out:
#       Año  Mes  FOB U$S Total  TOTAL KGS NETO
# 0    2021   12    26534264.41    3.535902e+07
# 1    2022   11    21028746.69    3.809373e+07
# 2    2011    8    20538153.84    4.072621e+07
# 3    2014   11    20307202.00    6.888001e+07
# 4    2013   11    19624307.13    5.940054e+07
# ..    ...  ...            ...             ...
# 166  2014    7       49776.65    5.500000e+04
# 167  2015    1       14518.06    2.970000e+04
# 168  2010    8       12000.00    4.000000e+04
# 169  2022    8         584.29    1.286700e+03
# 170  2014    4          93.90    2.756700e+02
#
# [171 rows x 4 columns]

# %%
fob_kgs_por_mes_ordenado.to_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data_2/fob_kgs/fob_kgs_por_mes_ordenado.csv')

# %% [markdown]
# Aqui termino con las importaciones

# %% [markdown]
# <h1>Data importaciones todos los fertilizantes 2024</h1>

# %% [markdown]
# En este punto, he querido extraer las importaciones de todos los fertilizantes (no solo de urea), para poder visualizar el mercado en el ultimo año, 2024.

# %%
fertilizantes_2024 = pd.read_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data /Importaciones Todos Fertilizantes 2024/fetilizantes 2024.csv')

# %%
fertilizantes_2024.head(25)
# Out:
#                                          RAZON SOCIAL  POTENCIAL UNO  \
# 0                                 SOLVESA ECUADOR S.A            NaN
# 1                                      BOSCHETTI S.A.            NaN
# 2                                      BOSCHETTI S.A.            NaN
# 3          FERTILIZANTES DEL PACIFICO FERPACIFIC S.A.            NaN
# 4                                      BOSCHETTI S.A.            NaN
# 5          FERTILIZANTES DEL PACIFICO FERPACIFIC S.A.            NaN
# 6                                       MORALVA CLTDA            NaN
# 7   AGRICOLA Y QUIMICA NACIONAL DEL COTOPAXI AGRON...            NaN
# 8   AGRICOLA Y QUIMICA NACIONAL DEL COTOPAXI AGRON...            NaN
# 9                      RODELFLOWERS COMPANIA LIMITADA            NaN
# 10                                      MORALVA CLTDA            NaN
# 11                             SHELVES ECUADOR S.A.S.            NaN
# 12                                      TRAVISER S.A.            NaN
# 13                                YARECUADOR CIA LTDA            NaN
# 14         FERTILIZANTES DEL PACIFICO FERPACIFIC S.A.            NaN
# 15         FERTILIZANTES DEL PACIFICO FERPACIFIC S.A.            NaN
# 16   DUPOCSA PROTECTORES QUIMICOS PARA EL CAMPO S. A.            NaN
# 17   DUPOCSA PROTECTORES QUIMICOS PARA EL CAMPO S. A.            NaN
# 18   DUPOCSA PROTECTORES QUIMICOS PARA EL CAMPO S. A.            NaN
# 19   DUPOCSA PROTECTORES QUIMICOS PARA EL CAMPO S. A.            NaN
# 20                                      EXPLOCEN C.A.            NaN
# 21                                      MORALVA CLTDA            NaN
# 22                                SOLVESA ECUADOR S.A            NaN
# 23                        FITO SANITARIO FITOSAN S.A.            NaN
# 24                                       AGRIPAC S.A.            NaN
#
#     NOMBRE COMERCIAL            RUC  \
# 0                NaN   990839557001
# 1                NaN   992392703001
# 2                NaN   992392703001
# 3                NaN   991441336001
# 4                NaN   992392703001
# 5                NaN   991441336001
# 6                NaN   992339640001
# 7                NaN   590060569001
# 8                NaN   590060569001
# 9                NaN  1791353420001
# 10               NaN   992339640001
# 11               NaN  1591726613001
# 12               NaN   992562560001
# 13               NaN  1792028140001
# 14               NaN   991441336001
# 15               NaN   991441336001
# 16               NaN   990856583001
# 17               NaN   990856583001
# 18               NaN   990856583001
# 19               NaN   990856583001
# 20               NaN  1790326136001
# 21               NaN   992339640001
# 22               NaN   990839557001
# 23               NaN   992945958001
# 24               NaN   990006687001
#
#                                         CONSIGNATARIO POSICION ARANCELARIA  \
# 0                                 SOLVESA ECUADOR S.A        3102.50.00.00
# 1                      TO THE ORDER OF BOSCHETTI S.A.        3102.10.90.00
# 2                                       BOSCHETTI S.A        3102.10.90.00
# 3          FERTILIZANTES DEL PACIFICO FERPACIFIC S.A.        3102.60.00.00
# 4                                       BOSCHETTI S.A        3102.10.90.00
# 5          FERTILIZANTES DEL PACIFICO FERPACIFIC S.A.        3102.60.00.00
# 6                                    MORALVA C. LTDA.        3102.21.00.00
# 7   AGRICOLA Y QUIMICA NACIONAL DEL COTOPAXI AGRON...        3102.90.90.00
# 8   AGRICOLA Y QUIMICA NACIONAL DEL COTOPAXI AGRON...        3102.90.90.00
# 9                              RODEL FLOWERS CIA LTDS        3102.90.90.00
# 10                                   MORALVA C. LTDA.        3102.21.00.00
# 11                             SHELVES ECUADOR S.A.S.        3102.90.90.00
# 12                                      TRAVISER S.A.        3102.90.90.00
# 13                                YARECUADOR CIA LTDA        3102.60.00.00
# 14         FERTILIZANTES DEL PACIFICO FERPACIFIC S.A.        3102.21.00.00
# 15         FERTILIZANTES DEL PACIFICO FERPACIFIC S.A.        3102.21.00.00
# 16     DUPOCSA  PROTECTORES QUIMICOS PARA EL CAMPO SA        3102.90.90.00
# 17     DUPOCSA  PROTECTORES QUIMICOS PARA EL CAMPO SA        3102.90.90.00
# 18     DUPOCSA  PROTECTORES QUIMICOS PARA EL CAMPO SA        3102.90.90.00
# 19     DUPOCSA  PROTECTORES QUIMICOS PARA EL CAMPO SA        3102.90.90.00
# 20                                        EXPLOCEN CA        3102.30.00.00
# 21                                   MORALVA C. LTDA.        3102.60.00.00
# 22                               SOLVESA ECUADOR S.A.        3102.21.00.00
# 23                        FITO SANITARIO FITOSAN S.A.        3102.90.90.00
# 24                                                NaN        3102.30.00.00
#
#     CODIGO COMPLEMENTARIO  CODIGO SUPLEMENTARIO  \
# 0                       0                     0
# 1                       0                     1
# 2                       0                     1
# 3                       0                     1
# 4                       0                     1
# 5                       0                     1
# 6                       0                     1
# 7                       0                     1
# 8                       0                     1
# 9                       0                     1
# 10                      0                     1
# 11                      0                     0
# 12                      0                     1
# 13                      0                     1
# 14                      0                     1
# 15                      0                     1
# 16                      0                     1
# 17                      0                     1
# 18                      0                     1
# 19                      0                     1
# 20                      0                     0
# 21                      0                     1
# 22                      0                     1
# 23                      0                     1
# 24                      0                     1
#
#                                  DESCRIPCION POSICION  \
# 0                                    Nitrato de sodio
# 1                                           Las demás
# 2                                           Las demás
# 3   Sales dobles y mezclas entre si de nitrato de ...
# 4                                           Las demás
# 5   Sales dobles y mezclas entre si de nitrato de ...
# 6                                   Sulfato de amonio
# 7                                           Los demás
# 8                                           Los demás
# 9                                           Los demás
# 10                                  Sulfato de amonio
# 11                                          Los demás
# 12                                          Los demás
# 13  Sales dobles y mezclas entre si de nitrato de ...
# 14                                  Sulfato de amonio
# 15                                  Sulfato de amonio
# 16                                          Los demás
# 17                                          Los demás
# 18                                          Los demás
# 19                                          Los demás
# 20    Nitrato de amonio, incluso en disolucion acuosa
# 21  Sales dobles y mezclas entre si de nitrato de ...
# 22                                  Sulfato de amonio
# 23                                          Los demás
# 24    Nitrato de amonio, incluso en disolucion acuosa
#
#                              DESCRIPCION DEL DESPACHO  \
# 0                  NITRATO DE SODIO, NITRATO DE SODIO
# 1        HEMOFAST, HEMOFAST FERTILIZANTES INORGANICOS
# 2           AZOFERT 55, AZOFERT FERTILIZANTE ORGANICO
# 3   CALCIUM NITRATE GRANULAR, FERTILIZANTE -100 TO...
# 4                         AZOFERT 55, IN 156 BIG BAGS
# 5      NITRATO DE CALCIO, FERTILIZANTE -200 TONELADAS
# 6   SULFATO DE AMONIO GRANULAR, SULFATO DE AMONIO ...
# 7                            N HIB CALCIUM, X 1000 LT
# 8                                 AQUA CAL, X 1000 LT
# 9                  LOWER 7, FERTILIZANTES PARA FLORES
# 10  SULFATO DE AMONIO GRANULAR, SULFATO DE AMONIO ...
# 11    CALCIUM NITRATE TETRAHYDRATE, NITRATO DE CALCIO
# 12                          UREA PHOSPHATE, EN BOLSAS
# 13                   FERTILIZANTE, YARA TERA CALCINIT
# 14    AMMONIUM SULPHATE, FERTILIZANTE -1500 TONELADAS
# 15     AMMONIUM SULPHATE, FERTILIZANTE -500 TONELADAS
# 16                                  CRECIFOL, NINGUNA
# 17                                  CRECIFOL, NINGUNA
# 18                                 ACTIVADOR, NINGUNA
# 19                                 MICRO MIX, NINGUNA
# 20                                   NITRATO, NITRATO
# 21  NITRATO DE CALCIO GRANULAR, NITRATO DE CALCIO ...
# 22     SULFATO AMONIO CRYSTAL, SULFATO AMONIO CRYSTAL
# 23  CU EDTA - NH4/ ADOB CU NH4 EDTA 15.5, NH4 EDTA...
# 24        NITRATO DE AMONIO, AMMONIUM NITRATE IN BULK
#
#                                    MARCA                        MODELO  \
# 0                              SIN MARCA                       SMODELO
# 1                              SIN MARCA               HEMOFAST BK1813
# 2                              SIN MARCA                    SIN MODELO
# 3                                 WEGROW  FERTILIZANTE DE USO AGRICOLA
# 4                              SIN MARCA                    AZOFERT 55
# 5                                 WEGROW  FERTILIZANTE DE USO AGRICOLA
# 6                              SIN MARCA                    SIN MODELO
# 7                              SIN MARCA                    SIN MODELO
# 8                              SIN MARCA                    SIN MODELO
# 9                              TRADECORP                    SIN MODELO
# 10                             SIN MARCA                    SIN MODELO
# 11                             SIN MARCA                    SIN MODELO
# 12                             SIN MARCA                    SIN MODELO
# 13                                  YARA                      30007630
# 14                             SIN MARCA  FERTILIZANTE DE USO AGRICOLA
# 15                             SIN MARCA  FERTILIZANTE DE USO AGRICOLA
# 16  MEZCLAS Y FERTILIZANTES S.A. DE C.V.                    SIN MODELO
# 17  MEZCLAS Y FERTILIZANTES S.A. DE C.V.                    SIN MODELO
# 18  MEZCLAS Y FERTILIZANTES S.A. DE C.V.                    SIN MODELO
# 19  MEZCLAS Y FERTILIZANTES S.A. DE C.V.                    SIN MODELO
# 20                                 ENAEX                      80001192
# 21                             SIN MARCA                    SIN MODELO
# 22                                SMARCA                       SMODELO
# 23                             SIN MARCA                    SIN MODELO
# 24                             SIN MARCA                    SIN MODELO
#
#             REFRENDO  ITEM  DAU FECHA DESPACHO FECHA EMBARQUE FECHA LLEGADA  \
# 0   2820241000000164     1  NaN     2024-01-01     2023-12-10    2023-12-25
# 1   2820241000003590     1  NaN     2024-01-02     2023-11-16    2023-12-30
# 2   2820241000003594     1  NaN     2024-01-02     2023-11-22    2023-12-30
# 3   2820241000003623     1  NaN     2024-01-02     2023-11-09    2023-12-30
# 4   2820241000003776     1  NaN     2024-01-02     2023-11-29    2023-12-30
# 5   2820241000004008     1  NaN     2024-01-02     2023-11-09    2023-12-30
# 6   2820241000004566     1  NaN     2024-01-02     2023-11-09    2023-12-30
# 7   2820241000007131     8  NaN     2024-01-02     2023-12-28    2023-12-31
# 8   2820241000007131     9  NaN     2024-01-02     2023-12-28    2023-12-31
# 9   2820241000008046     1  NaN     2024-01-02     2023-12-05    2023-12-30
# 10  2820241000009707     1  NaN     2024-01-03     2023-11-09    2023-12-30
# 11  2820241000010165     1  NaN     2024-01-03     2023-11-11    2023-12-31
# 12  2820241000010279     1  NaN     2024-01-03     2023-11-05    2023-12-29
# 13  2820241000013433     1  NaN     2024-01-03     2023-12-24    2024-01-01
# 14  2820241000016221     1  NaN     2024-01-04     2023-11-09    2023-12-30
# 15  2820241000016228     1  NaN     2024-01-04     2023-11-09    2023-12-30
# 16  2820241000017692     1  NaN     2024-01-04     2023-12-16    2023-12-31
# 17  2820241000017692     2  NaN     2024-01-04     2023-12-16    2023-12-31
# 18  2820241000017692     3  NaN     2024-01-04     2023-12-16    2023-12-31
# 19  2820241000017692     4  NaN     2024-01-04     2023-12-16    2023-12-31
# 20  2820241000020470     1  NaN     2024-01-04     2023-12-09    2023-12-31
# 21  2820241000022086     1  NaN     2024-01-05     2023-11-27    2023-12-25
# 22  2820241000023973     1  NaN     2024-01-05     2023-10-05    2023-12-16
# 23  2820241000024374     1  NaN     2024-01-05     2023-12-06    2024-01-03
# 24  2820241000024549     1  NaN     2024-01-05     2023-10-18    2024-01-17
#
#    FECHA LIQUIDACION  FECHA PAGO FECHA SALIDA ALMACEN                REGIMEN  \
# 0         2024-01-01  2024-01-02           2024-01-02  IMPORTACION A CONSUMO
# 1         2024-01-02  2024-01-02           2024-01-05  IMPORTACION A CONSUMO
# 2         2024-01-02  2024-01-02           2024-01-08  IMPORTACION A CONSUMO
# 3         2024-01-02  2024-01-03           2024-01-20  IMPORTACION A CONSUMO
# 4         2024-01-02  2024-01-02           2024-01-04  IMPORTACION A CONSUMO
# 5         2024-01-02  2024-01-02           2024-01-19  IMPORTACION A CONSUMO
# 6         2024-01-02  2024-01-02           2024-01-06  IMPORTACION A CONSUMO
# 7         2024-01-02  2024-01-02           2024-01-03  IMPORTACION A CONSUMO
# 8         2024-01-02  2024-01-02           2024-01-03  IMPORTACION A CONSUMO
# 9         2024-01-02  2024-01-03           2024-01-05  IMPORTACION A CONSUMO
# 10        2024-01-03  2024-01-03           2024-01-06  IMPORTACION A CONSUMO
# 11        2024-01-03  2024-01-04           2024-01-08  IMPORTACION A CONSUMO
# 12        2024-01-03  2024-01-03           2024-01-09  IMPORTACION A CONSUMO
# 13        2024-01-03  2024-01-03           2024-01-12  IMPORTACION A CONSUMO
# 14        2024-01-04  2024-01-08           2024-01-12  IMPORTACION A CONSUMO
# 15        2024-01-04  2024-01-08           2024-01-10  IMPORTACION A CONSUMO
# 16        2024-01-04  2024-01-04           2024-01-05  IMPORTACION A CONSUMO
# 17        2024-01-04  2024-01-04           2024-01-05  IMPORTACION A CONSUMO
# 18        2024-01-04  2024-01-04           2024-01-05  IMPORTACION A CONSUMO
# 19        2024-01-04  2024-01-04           2024-01-05  IMPORTACION A CONSUMO
# 20        2024-01-04  2024-01-05           2024-01-06  IMPORTACION A CONSUMO
# 21        2024-01-05  2024-01-05           2024-01-06  IMPORTACION A CONSUMO
# 22        2024-01-05  2024-01-08           2024-01-15  IMPORTACION A CONSUMO
# 23        2024-01-05  2024-01-08           2024-01-11  IMPORTACION A CONSUMO
# 24        2024-01-05  2024-01-08           2024-01-23  IMPORTACION A CONSUMO
#
#     NUMERO MANIFIESTO       MANIFIESTO CODIGO DOCUMENTO TRANSPORTE  \
# 0                 NaN  CEC2023MAEU0502     CEC2023MAEU050291500001
# 1                 NaN  CEC2023MSCU0480     CEC2023MSCU048001870000
# 2                 NaN  CEC2023MSCU0480     CEC2023MSCU048001200000
# 3                 NaN  CEC2023TBNA5015     CEC2023TBNA501500070000
# 4                 NaN  CEC2023MSCU0480     CEC2023MSCU048001280000
# 5                 NaN  CEC2023TBNA5015     CEC2023TBNA501500130000
# 6                 NaN  CEC2023TBNA5015     CEC2023TBNA501500150000
# 7                 NaN  CEC2023ONEU0048     CEC2023ONEU004810278557
# 8                 NaN  CEC2023ONEU0048     CEC2023ONEU004810278557
# 9                 NaN  CEC2023MSCU0490     CEC2023MSCU049000110000
# 10                NaN  CEC2023TBNA5015     CEC2023TBNA501500080000
# 11                NaN  CEC2023HLCU0914     CEC2023HLCU091461140000
# 12                NaN  CEC2023WHLU5692     CEC2023WHLU569200730000
# 13                NaN  CEC2024CMAU0001     CEC2024CMAU000190170000
# 14                NaN  CEC2023TBNA5015     CEC2023TBNA501500030000
# 15                NaN  CEC2023TBNA5015     CEC2023TBNA501500040000
# 16                NaN  CEC2023HLCU0914     CEC2023HLCU091492480000
# 17                NaN  CEC2023HLCU0914     CEC2023HLCU091492480000
# 18                NaN  CEC2023HLCU0914     CEC2023HLCU091492480000
# 19                NaN  CEC2023HLCU0914     CEC2023HLCU091492480000
# 20                NaN  CEC2023HLCU0914     CEC2023HLCU091492940000
# 21                NaN  CEC2023MAEU0504     CEC2023MAEU050400720000
# 22                NaN  CEC2023GEAR0007     CEC2023GEAR000700080000
# 23                NaN  CEC2024MSCU0001     CEC2024MSCU000101658564
# 24                NaN  CEC202477890004     CEC20247789000400010000
#
#    DOCUMENTO TRANSPORTE              ADUANA         PAIS ORIGEN  \
# 0      HLCUSCL231124355  GUAYAQUIL MARITIMO               CHILE
# 1          MEDUQP083320  GUAYAQUIL MARITIMO               ITALY
# 2          MEDUO6178885  GUAYAQUIL MARITIMO               ITALY
# 3          5R7042XGG042  GUAYAQUIL MARITIMO               CHINA
# 4          MEDUO6179735  GUAYAQUIL MARITIMO               ITALY
# 5          5R7042XGG048  GUAYAQUIL MARITIMO               CHINA
# 6          5R7042XGG050  GUAYAQUIL MARITIMO               CHINA
# 7      ONEYLIMD20948700  GUAYAQUIL MARITIMO                PERU
# 8      ONEYLIMD20948700  GUAYAQUIL MARITIMO                PERU
# 9          MEDUVB151037  GUAYAQUIL MARITIMO               SPAIN
# 10         5R7042XGG043  GUAYAQUIL MARITIMO               CHINA
# 11         MEDUUQ385368  GUAYAQUIL MARITIMO               CHINA
# 12           033D515074  GUAYAQUIL MARITIMO               CHINA
# 13     HLCUBO2231207601  GUAYAQUIL MARITIMO            COLOMBIA
# 14         5R7042XGG039  GUAYAQUIL MARITIMO               CHINA
# 15         5R7042XGG040  GUAYAQUIL MARITIMO               CHINA
# 16     HLCUME3231150114  GUAYAQUIL MARITIMO              MEXICO
# 17     HLCUME3231150114  GUAYAQUIL MARITIMO              MEXICO
# 18     HLCUME3231150114  GUAYAQUIL MARITIMO              MEXICO
# 19     HLCUME3231150114  GUAYAQUIL MARITIMO              MEXICO
# 20     HLCUSCL231130668  GUAYAQUIL MARITIMO               CHILE
# 21            233302427  GUAYAQUIL MARITIMO               CHINA
# 22         GSSWLWN8110B  GUAYAQUIL MARITIMO               CHINA
# 23         MEDUUG674614  GUAYAQUIL MARITIMO              POLAND
# 24                   13  GUAYAQUIL MARITIMO  RUSSIAN FEDERATION
#
#       PAIS PROCEDENCIA       PAIS EMBARQUE  \
# 0                CHILE               CHILE
# 1                ITALY               ITALY
# 2         PAISES BAJOS        PAISES BAJOS
# 3                CHINA               CHINA
# 4         PAISES BAJOS        PAISES BAJOS
# 5                CHINA               CHINA
# 6                CHINA               CHINA
# 7                 PERU                PERU
# 8                 PERU                PERU
# 9                SPAIN               SPAIN
# 10               CHINA               CHINA
# 11               CHINA               CHINA
# 12               CHINA               CHINA
# 13            COLOMBIA            COLOMBIA
# 14               CHINA               CHINA
# 15               CHINA               CHINA
# 16              MEXICO              MEXICO
# 17              MEXICO              MEXICO
# 18              MEXICO              MEXICO
# 19              MEXICO              MEXICO
# 20               CHILE               CHILE
# 21               CHINA               CHINA
# 22               CHINA               CHINA
# 23              POLAND              POLAND
# 24  RUSSIAN FEDERATION  RUSSIAN FEDERATION
#
#                        PUERTO EMBARQUE VIA TRANSPORTE  CONTENEDORES  \
# 0                        CLIQQ-IQUIQUE       MARITIMO           8.0
# 1                      ITSPE-LA SPEZIA       MARITIMO          10.0
# 2                      NLRTM-ROTTERDAM       MARITIMO          12.0
# 3                        CNXGG-XINGANG       MARITIMO           0.0
# 4                      NLRTM-ROTTERDAM       MARITIMO          12.0
# 5                        CNXGG-XINGANG       MARITIMO           0.0
# 6                        CNTSN-TIANJIN       MARITIMO           0.0
# 7                         PECLL-CALLAO       MARITIMO           2.0
# 8                         PECLL-CALLAO       MARITIMO           2.0
# 9                       ESVLC-VALENCIA       MARITIMO           1.0
# 10                       CNXGG-XINGANG       MARITIMO           0.0
# 11                CNTXG-TIANJINXINGANG       MARITIMO           5.0
# 12                CNTXG-TIANJINXINGANG       MARITIMO           2.0
# 13                     COCTG-CARTAGENA       MARITIMO          20.0
# 14                       CNXGG-XINGANG       MARITIMO           0.0
# 15                       CNXGG-XINGANG       MARITIMO           0.0
# 16                    MXZLO-MANZANILLO       MARITIMO           1.0
# 17                    MXZLO-MANZANILLO       MARITIMO           1.0
# 18                    MXZLO-MANZANILLO       MARITIMO           1.0
# 19                    MXZLO-MANZANILLO       MARITIMO           1.0
# 20                   CLANF-ANTOFAGASTA       MARITIMO          23.0
# 21                CNTXG-TIANJINXINGANG       MARITIMO           4.0
# 22                       CNTSN-TIANJIN       MARITIMO           0.0
# 23                        PLGDY-GDYNIA       MARITIMO           1.0
# 24  RULED-ST PETERSBURG (EX LENINGRAD)       MARITIMO           0.0
#
#                                              DEPOSITO     FOB U$S FLETE U$S  \
# 0                                05907400-INARPI S.A.  154,400.00      0.00
# 1                    05909025-CONTECON GUAYAQUIL S.A.  264,671.41      0.00
# 2                    05909025-CONTECON GUAYAQUIL S.A.  181,204.70      0.00
# 3                    05909025-CONTECON GUAYAQUIL S.A.   27,000.00      0.00
# 4                    05909025-CONTECON GUAYAQUIL S.A.  183,255.36      0.00
# 5                    05909025-CONTECON GUAYAQUIL S.A.   48,400.00      0.00
# 6                    05909025-CONTECON GUAYAQUIL S.A.  127,800.00      0.00
# 7                                05907400-INARPI S.A.    9,010.00    128.67
# 8                                05907400-INARPI S.A.    1,059.38     12.59
# 9                              05906960-NAPORTEC S.A.   15,116.00      0.00
# 10                   05909025-CONTECON GUAYAQUIL S.A.  127,145.28      0.00
# 11                               05907400-INARPI S.A.   39,150.00      0.00
# 12                               05907400-INARPI S.A.   60,786.40      0.00
# 13                      05777781-DPWORLD POSORJA S.A.  191,700.09      0.00
# 14                   05909025-CONTECON GUAYAQUIL S.A.  225,000.00      0.00
# 15                   05909025-CONTECON GUAYAQUIL S.A.   77,500.00      0.00
# 16                               05907400-INARPI S.A.    2,892.74      0.00
# 17                               05907400-INARPI S.A.    4,958.99      0.00
# 18                               05907400-INARPI S.A.    4,545.74      0.00
# 19                               05907400-INARPI S.A.    2,280.92      0.00
# 20                               05907400-INARPI S.A.  372,257.97      0.00
# 21                   05909025-CONTECON GUAYAQUIL S.A.   25,688.00      0.00
# 22  05909272-FERTISA, FERTILIZANTES, TERMINALES I ...   11,991.25      0.00
# 23                   05909025-CONTECON GUAYAQUIL S.A.  111,134.40      0.00
# 24                           05777783-STOREOCEAN S.A.  805,035.00      0.00
#
#    SEGURO U$S     CIF U$S            FACTURA VALOR FACTURA U$S  \
# 0      153.00  154,553.00                423        154,400.00
# 1    2,806.60  267,478.00  2023-FEST-0000413        264,671.41
# 2      129.82  181,334.53  2023-FEST-0000423        181,204.70
# 3       44.80   27,044.80            5001563         27,000.00
# 4    1,962.37  185,217.73  2023-FEST-0000438        183,255.36
# 5       79.52   48,479.52            5001569         48,400.00
# 6      225.00  128,025.00           12199-72        127,800.00
# 7       19.46    9,158.13       F003-0000174         99,778.83
# 8        2.29    1,074.26       F003-0000174         99,778.83
# 9      151.16   15,267.16         6483005528         15,116.00
# 10     225.00  127,370.28         TC23090230        127,145.28
# 11     588.50   39,738.50         SN20231013         39,150.00
# 12     224.69   61,011.09              00008         60,786.40
# 13   1,917.00  193,617.09          103153370        191,700.09
# 14     399.00  225,399.00      2023SHY-AS206        225,000.00
# 15     136.50   77,636.50       2023MJ-AS207         77,500.00
# 16       4.93    2,897.67                624         14,678.39
# 17       8.45    4,967.44                624         14,678.39
# 18       7.74    4,553.48                624         14,678.39
# 19       3.88    2,284.81                624         14,678.39
# 20   5,403.21  377,661.19              13307        372,257.97
# 21      46.33   25,734.33           12199-71         25,688.00
# 22      20.00   12,011.25    SLC-Y-AS2308243         11,991.25
# 23     911.62  112,046.02    DEX0065/11/2023        111,134.40
# 24     868.59  805,903.56       I-23-0005548        805,035.00
#
#    BASE IMPONIBLE U$S      KGS NETO  KGS BRUTO      UNIDADES      TIPO UNIDAD  \
# 0          170,153.00    200,000.00        0.0    200,000.00  KILOGRAMO BRUTO
# 1          283,466.19    239,880.00        0.0    243,080.00  KILOGRAMO BRUTO
# 2          194,316.61    308,233.00        0.0    311,353.00  KILOGRAMO BRUTO
# 3           32,044.80    100,000.00        0.0    100,400.00  KILOGRAMO BRUTO
# 4          198,199.81    311,488.00        0.0    314,608.00  KILOGRAMO BRUTO
# 5           56,879.52    200,000.00        0.0    200,480.00  KILOGRAMO BRUTO
# 6          150,225.00    600,000.00        0.0    600,000.00  KILOGRAMO BRUTO
# 7            9,158.13     13,900.00        0.0     14,496.66  KILOGRAMO BRUTO
# 8            1,074.26      1,360.00        0.0      1,418.38  KILOGRAMO BRUTO
# 9           16,884.16     14,400.00        0.0     15,335.00  KILOGRAMO BRUTO
# 10         150,225.00    600,000.00        0.0    600,000.00  KILOGRAMO BRUTO
# 11          49,588.50    135,000.00        0.0    135,540.00  KILOGRAMO BRUTO
# 12          64,247.09     57,600.00        0.0     57,600.00  KILOGRAMO BRUTO
# 13         206,131.59    540,000.00        0.0    542,000.00  KILOGRAMO BRUTO
# 14         285,399.00  1,500,000.00        0.0  1,506,600.00  KILOGRAMO BRUTO
# 15          97,636.50    500,000.00        0.0    501,200.00  KILOGRAMO BRUTO
# 16           3,238.93        720.72        0.0        749.72  KILOGRAMO BRUTO
# 17           5,552.45      1,395.24        0.0      1,451.39  KILOGRAMO BRUTO
# 18           5,089.74      1,376.76        0.0      1,432.16  KILOGRAMO BRUTO
# 19           2,553.89      3,000.00        0.0      3,120.73  KILOGRAMO BRUTO
# 20         414,736.97    500,000.00        0.0    507,380.00  KILOGRAMO BRUTO
# 21          30,934.33    114,400.00        0.0    114,400.00  KILOGRAMO BRUTO
# 22          14,595.00     66,250.00        0.0     66,250.00  KILOGRAMO BRUTO
# 23         113,746.83     16,250.00        0.0     16,460.00  KILOGRAMO BRUTO
# 24       1,069,903.62  3,300,000.00        0.0  3,300,000.00  KILOGRAMO BRUTO
#
#     PRECIO UNITARIO U$S CANTIDAD COMERCIAL UNIDAD COMERCIAL  \
# 0                  0.77         200,000.00               KG
# 1                  1.09         239,880.00               KG
# 2                  0.58         308,233.00               KG
# 3                  0.27         100,000.00               KG
# 4                  0.58         311,488.00               KG
# 5                  0.24         200,000.00               KG
# 6                  0.21         600,000.00               KG
# 7                  0.62          10,000.00                L
# 8                  0.75           1,000.00                L
# 9                  0.99           9,600.00                L
# 10                 0.21         600,000.00               KG
# 11                 0.29             135.00               TM
# 12                 1.06              57.60               TM
# 13                 0.35             540.00               TM
# 14                 0.15       1,500,000.00               KG
# 15                 0.15         500,000.00               KG
# 16                 3.86             462.00                L
# 17                 3.42             924.00                L
# 18                 3.17             924.00                L
# 19                 0.73           3,000.00               KG
# 20                 0.73         500,000.00               KG
# 21                 0.22         114,400.00               KG
# 22                 0.18          66,250.00               KG
# 23                 6.75          16,250.00               KG
# 24                 0.24           3,300.00               TM
#
#    PRECIO UNITARIO COMERCIAL U$S TIPO UNIDAD NOMENCLADOR  ADVAL MONEDA  \
# 0                           0.77           kg, Kilogramo    0.0    DOL
# 1                           1.10           kg, Kilogramo    0.0    DOL
# 2                           0.59           kg, Kilogramo    0.0    DOL
# 3                           0.27           kg, Kilogramo    0.0    DOL
# 4                           0.59           kg, Kilogramo    0.0    DOL
# 5                           0.24           kg, Kilogramo    0.0    DOL
# 6                           0.21           kg, Kilogramo    0.0    DOL
# 7                           0.90           kg, Kilogramo    0.0    DOL
# 8                           1.06           kg, Kilogramo    0.0    DOL
# 9                           1.57           kg, Kilogramo    0.0    DOL
# 10                          0.21           kg, Kilogramo    0.0    DOL
# 11                        290.00           kg, Kilogramo    0.0    DOL
# 12                      1,055.32           kg, Kilogramo    0.0    DOL
# 13                        355.00           kg, Kilogramo    0.0    DOL
# 14                          0.15           kg, Kilogramo    0.0    DOL
# 15                          0.16           kg, Kilogramo    0.0    DOL
# 16                          6.26           kg, Kilogramo    0.0    DOL
# 17                          5.37           kg, Kilogramo    0.0    DOL
# 18                          4.92           kg, Kilogramo    0.0    DOL
# 19                          0.76           kg, Kilogramo    0.0    DOL
# 20                          0.74           kg, Kilogramo    0.0    DOL
# 21                          0.22           kg, Kilogramo    0.0    DOL
# 22                          0.18           kg, Kilogramo    0.0    DOL
# 23                          6.84           kg, Kilogramo    0.0    DOL
# 24                        243.95           kg, Kilogramo    0.0    DOL
#
#                                            EMBARCADOR INCOTERM  \
# 0                            COSAYACH EXPORTADORA S A      CFR
# 1                                       TEN COM GROUP      CFR
# 2                                   TEN COM GROUP SRL      CFR
# 3                                           WEGROW AG      CFR
# 4                               VIA PER FORMIGINE 45D      CFR
# 5                                           WEGROW AG      CFR
# 6                           STAR GRACE MINING CO LTD.      CFR
# 7                                     STOLLER PERU SA      FOB
# 8                                     STOLLER PERU SA      FOB
# 9                 TRADE CORPORATION INTERNATIONAL S.A      CIP
# 10        TIANJIN CROWN CHAMPION INDUSTRIAL CO., LTD.      CFR
# 11                SHANDONG NOVAOIL TECHNOLOGY CO.,LTD      CIF
# 12                                      P&T GROUP LLC      CPT
# 13                                 YARA COLOMBIA S.A.      CIP
# 14              ZHONGSHUO INTERNATIONAL TRADE CO. LTD      CFR
# 15              ZHONGSHUO INTERNATIONAL TRADE CO. LTD      CFR
# 16               MEZCLAS Y FERTILIZANTES S.A. DE C.V.      CFR
# 17               MEZCLAS Y FERTILIZANTES S.A. DE C.V.      CFR
# 18               MEZCLAS Y FERTILIZANTES S.A. DE C.V.      CFR
# 19               MEZCLAS Y FERTILIZANTES S.A. DE C.V.      CFR
# 20                                         ENAEX S.A.      CIF
# 21                          STAR GRACE MINING CO LTD.      CFR
# 22                       SOLINC INDUSTRIAL CO LIMITED      CFR
# 23  PRZEDSIEBIORSTWO PRODUKCYJNO CONSULTINGOWE ADO...      CFR
# 24                                   NITRON GROUP LLC      CFR
#
#                                     CODIGO LIBERACION ESTADO MERCADERIA  \
# 0   0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 1   0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 2   0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 3   0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 4   0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 5   0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 6   0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 7   0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 8   0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 9   0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 10  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 11                                                NaN             NUEVO
# 12  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 13  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 14  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 15  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 16  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 17  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 18  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 19  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 20                                                NaN             NUEVO
# 21  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 22  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 23  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
# 24  0640-TRANSFERENCIAS E IMPORTACIONES CON TARIFA...             NUEVO
#
#     CLASE MERCADERIA PAIS DESTINO TOTAL FOB U$S TOTAL FLETE U$S  \
# 0                NaN      ECUADOR    154,400.00            0.00
# 1                NaN      ECUADOR    264,671.41            0.00
# 2                NaN      ECUADOR    181,204.70            0.00
# 3                NaN      ECUADOR     27,000.00            0.00
# 4                NaN      ECUADOR    183,255.36            0.00
# 5                NaN      ECUADOR     48,400.00            0.00
# 6                NaN      ECUADOR    127,800.00            0.00
# 7                NaN      ECUADOR     99,778.83          450.01
# 8                NaN      ECUADOR           NaN             NaN
# 9                NaN      ECUADOR     15,116.00            0.00
# 10               NaN      ECUADOR    127,145.28            0.00
# 11               NaN      ECUADOR     39,150.00            0.00
# 12               NaN      ECUADOR     60,786.40            0.00
# 13               NaN      ECUADOR    191,700.09            0.00
# 14               NaN      ECUADOR    225,000.00            0.00
# 15               NaN      ECUADOR     77,500.00            0.00
# 16               NaN      ECUADOR     14,678.39            0.00
# 17               NaN      ECUADOR           NaN             NaN
# 18               NaN      ECUADOR           NaN             NaN
# 19               NaN      ECUADOR           NaN             NaN
# 20               NaN      ECUADOR    372,257.97            0.00
# 21               NaN      ECUADOR     25,688.00            0.00
# 22               NaN      ECUADOR     11,991.25            0.00
# 23               NaN      ECUADOR    111,134.40            0.00
# 24               NaN      ECUADOR    805,035.00            0.00
#
#    TOTAL SEGURO U$S TOTAL CIF U$S TOTAL KGS NETO  TOTAL KGS BRUTO  \
# 0            153.00    154,553.00     200,000.00              0.0
# 1          2,806.60    267,478.00     239,880.00              0.0
# 2            129.82    181,334.53     308,233.00              0.0
# 3             44.80     27,044.80     100,000.00              0.0
# 4          1,962.37    185,217.73     311,488.00              0.0
# 5             79.52     48,479.52     200,000.00              0.0
# 6            225.00    128,025.00     600,000.00              0.0
# 7            215.51    100,444.35      48,613.28              0.0
# 8               NaN           NaN            NaN              NaN
# 9            151.16     15,267.16      14,400.00              0.0
# 10           225.00    127,370.28     600,000.00              0.0
# 11           588.50     39,738.50     135,000.00              0.0
# 12           224.69     61,011.09      57,600.00              0.0
# 13         1,917.00    193,617.09     540,000.00              0.0
# 14           399.00    225,399.00   1,500,000.00              0.0
# 15           136.50     77,636.50     500,000.00              0.0
# 16            25.00     14,703.40       6,492.72              0.0
# 17              NaN           NaN            NaN              NaN
# 18              NaN           NaN            NaN              NaN
# 19              NaN           NaN            NaN              NaN
# 20         5,403.21    377,661.19     500,000.00              0.0
# 21            46.33     25,734.33     114,400.00              0.0
# 22            20.00     12,011.25      66,250.00              0.0
# 23           911.62    112,046.02      16,250.00              0.0
# 24           868.59    805,903.56   3,300,000.00              0.0
#
#    TOTAL BASE IMPONIBLE  TOTAL CANTIDAD BULTOS TOTAL AJUSTES  \
# 0            170,153.00                    0.0          0.00
# 1            283,466.19                    0.0          0.00
# 2            194,316.61                    0.0          0.00
# 3             32,044.80                    0.0          0.00
# 4            198,199.81                    0.0          0.00
# 5             56,879.52                    0.0          0.00
# 6            150,225.00                    0.0          0.00
# 7            100,444.35                    0.0          0.00
# 8                   NaN                    NaN           NaN
# 9             16,884.16                    0.0          0.00
# 10           150,225.00                    0.0          0.00
# 11            49,588.50                    0.0          0.00
# 12            64,247.09                    0.0          0.00
# 13           206,131.59                    0.0          0.00
# 14           285,399.00                    0.0          0.00
# 15            97,636.50                    0.0          0.00
# 16            16,435.01                    0.0          0.00
# 17                  NaN                    NaN           NaN
# 18                  NaN                    NaN           NaN
# 19                  NaN                    NaN           NaN
# 20           414,736.97                    0.0          0.00
# 21            30,934.33                    0.0          0.00
# 22            14,595.00                    0.0          0.00
# 23           113,746.83                    0.0          0.00
# 24         1,069,903.62                    0.0          0.00
#
#     TOTAL OTROS AJUSTES  CLASE  VERIFICADOR  \
# 0                   0.0    NaN          NaN
# 1                   0.0    NaN          NaN
# 2                   0.0    NaN          NaN
# 3                   0.0    NaN          NaN
# 4                   0.0    NaN          NaN
# 5                   0.0    NaN          NaN
# 6                   0.0    NaN          NaN
# 7                   0.0    NaN          NaN
# 8                   NaN    NaN          NaN
# 9                   0.0    NaN          NaN
# 10                  0.0    NaN          NaN
# 11                  0.0    NaN          NaN
# 12                  0.0    NaN          NaN
# 13                  0.0    NaN          NaN
# 14                  0.0    NaN          NaN
# 15                  0.0    NaN          NaN
# 16                  0.0    NaN          NaN
# 17                  NaN    NaN          NaN
# 18                  NaN    NaN          NaN
# 19                  NaN    NaN          NaN
# 20                  0.0    NaN          NaN
# 21                  0.0    NaN          NaN
# 22                  0.0    NaN          NaN
# 23                  0.0    NaN          NaN
# 24                  0.0    NaN          NaN
#
#                                      AGENTE AFIANZADO             NAVE  \
# 0                01777779: JIMENEZ QUIROZ BORIS LENIN    MAERSK ACADIA
# 1               01903052: MOREIRA NARANJO JAIME MAURO     MSC KATYA R.
# 2   01900022: SOLUCIONES INTEGRALES DE LOGISTICA Y...     MSC KATYA R.
# 3                             01777837: VARYMPEX S.A.    PACIFIC NEXUS
# 4               01903052: MOREIRA NARANJO JAIME MAURO     MSC KATYA R.
# 5                             01777837: VARYMPEX S.A.    PACIFIC NEXUS
# 6   01901316: ORGANIZACION COMERCIAL Y ADUANERA MA...    PACIFIC NEXUS
# 7                01777779: JIMENEZ QUIROZ BORIS LENIN          ESSENCE
# 8                01777779: JIMENEZ QUIROZ BORIS LENIN          ESSENCE
# 9            01777855: SERRANO RODRIGUEZ MIGUEL ANGEL    MSC MIRELLA R
# 10  01901316: ORGANIZACION COMERCIAL Y ADUANERA MA...    PACIFIC NEXUS
# 11               01777806: JATIVA LOPEZ WILMER HERNAN            VALOR
# 12  01901316: ORGANIZACION COMERCIAL Y ADUANERA MA...      WAN HAI 621
# 13  01902441: TORRES & TORRES AGENTES DE ADUANAS T...  CMA CGM ESTELLE
# 14                            01777837: VARYMPEX S.A.    PACIFIC NEXUS
# 15                            01777837: VARYMPEX S.A.    PACIFIC NEXUS
# 16          01777805: ROBLES MEDRANO ANDREA ESTEFANIA            VALOR
# 17          01777805: ROBLES MEDRANO ANDREA ESTEFANIA            VALOR
# 18          01777805: ROBLES MEDRANO ANDREA ESTEFANIA            VALOR
# 19          01777805: ROBLES MEDRANO ANDREA ESTEFANIA            VALOR
# 20                               01777833: CORADUANAS            VALOR
# 21  01901316: ORGANIZACION COMERCIAL Y ADUANERA MA...      MAERSK ELBA
# 22               01777779: JIMENEZ QUIROZ BORIS LENIN      LAWIN ARROW
# 23               01777779: JIMENEZ QUIROZ BORIS LENIN    MSC ARUSHI R.
# 24  01902441: TORRES & TORRES AGENTES DE ADUANAS T...       OKOLCHITSA
#
#                                    AGENCIA TRANSPORTE  \
# 0                                                 NaN
# 1   02908390-MEDITERRANEAN SHIPPING COMPANY DEL EC...
# 2   02908390-MEDITERRANEAN SHIPPING COMPANY DEL EC...
# 3                                                 NaN
# 4   02908390-MEDITERRANEAN SHIPPING COMPANY DEL EC...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   02908390-MEDITERRANEAN SHIPPING COMPANY DEL EC...
# 10                                                NaN
# 11  02908390-MEDITERRANEAN SHIPPING COMPANY DEL EC...
# 12      07908255-AGENCIA MARITIMA GLOBAL MARGLOBAL SA
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                   02907986-MAERSK DEL ECUADOR C.A.
# 22  02777787-REMAR REPRESENTACIONES MARITIMAS DEL ...
# 23                                                NaN
# 24                        02777789-HANSAMARITIME S.A.
#
#                                    EMPRESA TRANSPORTE  \
# 0                   02777827-HAPAG-LLOYD ECUADOR S.A.
# 1   02908390-MEDITERRANEAN SHIPPING COMPANY DEL EC...
# 2   02908390-MEDITERRANEAN SHIPPING COMPANY DEL EC...
# 3   02908903-AGENCIA TECNICO MARITIMA TECNISEA C. ...
# 4   02908390-MEDITERRANEAN SHIPPING COMPANY DEL EC...
# 5   02908903-AGENCIA TECNICO MARITIMA TECNISEA C. ...
# 6   02908903-AGENCIA TECNICO MARITIMA TECNISEA C. ...
# 7   02777845-OCEAN NETWORK EXPRESS (ECUADOR) ONEEC...
# 8   02777845-OCEAN NETWORK EXPRESS (ECUADOR) ONEEC...
# 9   02908390-MEDITERRANEAN SHIPPING COMPANY DEL EC...
# 10  02908903-AGENCIA TECNICO MARITIMA TECNISEA C. ...
# 11  02908390-MEDITERRANEAN SHIPPING COMPANY DEL EC...
# 12      02901130-AGENCIA MARITIMA GLOBAL MARGLOBAL SA
# 13                  02777827-HAPAG-LLOYD ECUADOR S.A.
# 14  02908903-AGENCIA TECNICO MARITIMA TECNISEA C. ...
# 15  02908903-AGENCIA TECNICO MARITIMA TECNISEA C. ...
# 16                  02777827-HAPAG-LLOYD ECUADOR S.A.
# 17                  02777827-HAPAG-LLOYD ECUADOR S.A.
# 18                  02777827-HAPAG-LLOYD ECUADOR S.A.
# 19                  02777827-HAPAG-LLOYD ECUADOR S.A.
# 20                  02777827-HAPAG-LLOYD ECUADOR S.A.
# 21                   02907986-MAERSK DEL ECUADOR C.A.
# 22  02901112-REMAR REPRESENTACIONES MARITIMAS DEL ...
# 23  02908390-MEDITERRANEAN SHIPPING COMPANY DEL EC...
# 24                        02777789-HANSAMARITIME S.A.
#
#                                      AFORADOR FECHA AFORO  \
# 0                                         NaN  0000-00-00
# 1                                         NaN  0000-00-00
# 2                                         NaN  0000-00-00
# 3        MACUNA-ACU??A ZHINGRI MARIA FERNANDA  0000-00-00
# 4                                         NaN  0000-00-00
# 5      JVZAMORA-ZAMORA ESCOBAR JOFFRE VICENTE  0000-00-00
# 6                                         NaN  0000-00-00
# 7        PALOPEZ-LOPEZ POTES PAMELA ELIZABETH  0000-00-00
# 8        PALOPEZ-LOPEZ POTES PAMELA ELIZABETH  0000-00-00
# 9                                         NaN  0000-00-00
# 10                                        NaN  0000-00-00
# 11                                        NaN  0000-00-00
# 12  RMACIAS-MACIAS ORELLANA RICHARD FRANCISCO  0000-00-00
# 13                                        NaN  0000-00-00
# 14     ERIVERA-RIVERA HERNANDEZ ELENA LISBETH  0000-00-00
# 15       PALOPEZ-LOPEZ POTES PAMELA ELIZABETH  0000-00-00
# 16                                        NaN  0000-00-00
# 17                                        NaN  0000-00-00
# 18                                        NaN  0000-00-00
# 19                                        NaN  0000-00-00
# 20                                        NaN  0000-00-00
# 21           MAPONCE-PONCE GARCIA MARIA ELENA  0000-00-00
# 22                                        NaN  0000-00-00
# 23           MAPONCE-PONCE GARCIA MARIA ELENA  0000-00-00
# 24                                        NaN  0000-00-00
#
#                 TIPO AFORO                 ACTIVIDAD PRINCIPAL DEL IMPORTADOR  \
# 0         AFORO AUTOMATICO         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 1         AFORO AUTOMATICO         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 2         AFORO AUTOMATICO         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 3   AFORO FISICO INTRUSIVO  0140-ACTIVIDADES DE SERVICIOS AGRICOLAS Y GANA...
# 4         AFORO AUTOMATICO         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 5   AFORO FISICO INTRUSIVO  0140-ACTIVIDADES DE SERVICIOS AGRICOLAS Y GANA...
# 6         AFORO AUTOMATICO                                         9993-OTROS
# 7         AFORO DOCUMENTAL         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 8         AFORO DOCUMENTAL         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 9         AFORO AUTOMATICO  5121-VENTA AL POR MAYOR DE MATERIAS PRIMAS AGR...
# 10        AFORO AUTOMATICO                                         9993-OTROS
# 11        AFORO AUTOMATICO                                                NaN
# 12  AFORO FISICO INTRUSIVO                                         9993-OTROS
# 13        AFORO AUTOMATICO  0140-ACTIVIDADES DE SERVICIOS AGRICOLAS Y GANA...
# 14  AFORO FISICO INTRUSIVO  0140-ACTIVIDADES DE SERVICIOS AGRICOLAS Y GANA...
# 15        AFORO DOCUMENTAL  0140-ACTIVIDADES DE SERVICIOS AGRICOLAS Y GANA...
# 16        AFORO AUTOMATICO         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 17        AFORO AUTOMATICO         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 18        AFORO AUTOMATICO         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 19        AFORO AUTOMATICO         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 20        AFORO AUTOMATICO         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 21        AFORO DOCUMENTAL                                         9993-OTROS
# 22        AFORO AUTOMATICO         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 23        AFORO DOCUMENTAL         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
# 24        AFORO AUTOMATICO         5190-VENTA AL POR MAYOR DE OTROS PRODUCTOS
#
#                              DIRECCION DEL IMPORTADOR  \
# 0              CASUARINA 100 Y VIA A DAULE, GUAYAQUIL
# 1   AV. JUAN TANCA MARENGO KM 0.5 211EDIFICIO FAMO...
# 2   AV. JUAN TANCA MARENGO KM 0.5 211EDIFICIO FAMO...
# 3                                 KM 16,5 VIA A DAULE
# 4   AV. JUAN TANCA MARENGO KM 0.5 211EDIFICIO FAMO...
# 5                                 KM 16,5 VIA A DAULE
# 6   VIA A LA COSTA KM 6 1/2 LA VISTA SAN EDUARDO C...
# 7   JOSEGUANGO BAJO / PANAMERICANA NORTE S/N Y SEC...
# 8   JOSEGUANGO BAJO / PANAMERICANA NORTE S/N Y SEC...
# 9                  FRANCISCO ROBLES E4 136 Y AMAZONAS
# 10  VIA A LA COSTA KM 6 1/2 LA VISTA SAN EDUARDO C...
# 11  AV. GENERAL RUMINAHUI AND AV. GENERAL PINTAG, ...
# 12  AV LEOPOLDO CARRERA EDIF OLIVOS BUSINESS CENTE...
# 13            KM 1 5 SOLAR 120 Y LOS ARCOS EDIF LOS A
# 14                                KM 16,5 VIA A DAULE
# 15                                KM 16,5 VIA A DAULE
# 16        PARA EL CAMPO VIA DURAN - TAMBO KM 9, DURAN
# 17        PARA EL CAMPO VIA DURAN - TAMBO KM 9, DURAN
# 18        PARA EL CAMPO VIA DURAN - TAMBO KM 9, DURAN
# 19        PARA EL CAMPO VIA DURAN - TAMBO KM 9, DURAN
# 20      AVENIDA CORUNA E25-58 Y AVENIDA 12 DE OCTUBRE
# 21  VIA A LA COSTA KM 6 1/2 LA VISTA SAN EDUARDO C...
# 22             CASUARINA 100 Y VIA A DAULE, GUAYAQUIL
# 23               VIA DURAN TAMBO- KM 4.5 C.C.SAI BABA
# 24              CORDOVA 623 Y PADRE SOLANO, GUAYAQUIL
#
#     DIRECCION DEL CONSIGNATARIO  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
#
#                                       CONSOLIDADORA
# 0                                       TOLEPU S.A.
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7   AIR MAINLAND & SEA CARGO SERVICE S.A. AMSECARGO
# 8   AIR MAINLAND & SEA CARGO SERVICE S.A. AMSECARGO
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20                                              NaN
# 21                                              NaN
# 22                                              NaN
# 23  AIR MAINLAND & SEA CARGO SERVICE S.A. AMSECARGO
# 24                                              NaN

# %% [markdown]
# Vamos a ver cuantas importaciones hay por posicion arancelaria

# %%
fertilizantes_2024['POSICION ARANCELARIA'].value_counts()
# Out:
# POSICION ARANCELARIA
# 3102.90.90.00    355
# 3102.21.00.00    195
# 3102.10.10.00    125
# 3102.60.00.00     85
# 3102.10.90.00     63
# 3102.30.00.00     57
# 3102.50.00.00     27
# 3102.29.00.00      9
# 3102.90.10.00      8
# 3102.80.00.00      3
# Name: count, dtype: int64

# %% [markdown]
# Nos quedamos solo con las columnas que nos sirven

# %%
data_total_4 = ['POSICION ARANCELARIA', 'DESCRIPCION POSICION', 'FOB U$S', 'PAIS DESTINO', 'KGS NETO']
fertilizantes_2024 = fertilizantes_2024[data_total_4]

fertilizantes_2024
# Out:
#     POSICION ARANCELARIA                               DESCRIPCION POSICION  \
# 0          3102.50.00.00                                   Nitrato de sodio
# 1          3102.10.90.00                                          Las demás
# 2          3102.10.90.00                                          Las demás
# 3          3102.60.00.00  Sales dobles y mezclas entre si de nitrato de ...
# 4          3102.10.90.00                                          Las demás
# ..                   ...                                                ...
# 922        3102.60.00.00  Sales dobles y mezclas entre si de nitrato de ...
# 923        3102.21.00.00                                  Sulfato de amonio
# 924        3102.10.90.00                                          Las demás
# 925        3102.21.00.00                                  Sulfato de amonio
# 926        3102.60.00.00  Sales dobles y mezclas entre si de nitrato de ...
#
#         FOB U$S PAIS DESTINO      KGS NETO
# 0    154,400.00      ECUADOR    200,000.00
# 1    264,671.41      ECUADOR    239,880.00
# 2    181,204.70      ECUADOR    308,233.00
# 3     27,000.00      ECUADOR    100,000.00
# 4    183,255.36      ECUADOR    311,488.00
# ..          ...          ...           ...
# 922   43,578.44      ECUADOR    200,000.00
# 923  240,975.00      ECUADOR  1,500,000.00
# 924   56,191.05      ECUADOR     67,200.00
# 925   76,117.50      ECUADOR    497,500.00
# 926   15,470.00      ECUADOR     65,000.00
#
# [927 rows x 5 columns]

# %% [markdown]
# Cambio los nombres de las filas, por claridad

# %%
fertilizantes_2024 = fertilizantes_2024.rename(columns={
    'FOB U$S': 'Valor Total',
    'KGS NETO': 'Volumen Total en KGS'
})

# %% [markdown]
# Ahora contamos por posicion

# %%
fertilizantes_2024['DESCRIPCION POSICION'].value_counts()
# Out:
# DESCRIPCION POSICION
# Los demás                                                                                                            355
# Sulfato de amonio                                                                                                    195
# Con un porcentaje de nitrógeno superior o igual a 45% pero inferior o igual a 46% en  peso (calidad fertilizante)    125
# Sales dobles y mezclas entre si de nitrato de calcio y nitrato de amonio                                              85
# Las demás                                                                                                             63
# Nitrato de amonio, incluso en disolucion acuosa                                                                       57
# Nitrato de sodio                                                                                                      27
# Las demas                                                                                                              9
# Mezclas de nitrato de calcio con nitrato de magnesio                                                                   8
# Mezclas de urea con nitrato de amonio en disolución acuosa o amoniacal                                                 3
# Name: count, dtype: int64

# %% [markdown]
# Cambiamos la fila de KGs y Valor Total a tipo float

# %%
columns_to_clean_2 = ['Valor Total', 'Volumen Total en KGS']

for column in columns_to_clean_2:
    fertilizantes_2024.loc[:, column] = (
        fertilizantes_2024[column]
        .astype(str)  
        .str.replace('$', '', regex=False)  
        .str.replace(',', '', regex=False)  
        .str.strip()  
    )

fertilizantes_2024[columns_to_clean_2] = fertilizantes_2024[columns_to_clean_2].apply(pd.to_numeric, errors='coerce')

# %%
fertilizantes_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 927 entries, 0 to 926
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   POSICION ARANCELARIA  927 non-null    object
#  1   DESCRIPCION POSICION  927 non-null    object
#  2   Valor Total           927 non-null    float64
#  3   PAIS DESTINO          927 non-null    object
#  4   Volumen Total en KGS  927 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 36.3+ KB

# %% [markdown]
# Veamos cuanto tengo en total, de volumen, por posicion arancelaria

# %%
fertilizantes_2024.groupby('POSICION ARANCELARIA')['Volumen Total en KGS'].sum().sort_values(ascending=False)
# Out:
# POSICION ARANCELARIA
# 3102.10.10.00    2.706688e+08
# 3102.21.00.00    1.575590e+08
# 3102.30.00.00    8.050914e+07
# 3102.90.90.00    3.722665e+07
# 3102.60.00.00    2.925940e+07
# 3102.10.90.00    5.790904e+06
# 3102.50.00.00    1.611881e+06
# 3102.29.00.00    2.043600e+05
# 3102.90.10.00    2.716842e+04
# 3102.80.00.00    8.672000e+03
# Name: Volumen Total en KGS, dtype: float64

# %% [markdown]
# Me dan valores realistas, asi que bien.

# %% [markdown]
# Ahora compruebo NaNes y 0

# %%
fertilizantes_2024["Volumen Total en KGS"].isna().sum()
# Out:
# np.int64(0)

# %%
fertilizantes_2024["POSICION ARANCELARIA"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Ahora que tengo las cantidades convertidas a numeros, voy a cambiar los nombres de las posiciones arancelarias, al nombre de su tipo de fertilizante.

# %%
mapeo_posiciones = {
    '3102.90.90.00': 'Nitrogenados',
    '3102.21.00.00': 'Sulfato de Amonio',
    '3102.10.10.00': 'Urea',
    '3102.60.00.00': 'Nitrogenados',
    '3102.10.90.00': 'Urea',
    '3102.30.00.00': 'Sulfato de Amonio',
    '3102.50.00.00': 'Urea',
    '3102.29.00.00': 'Urea',
    '3102.90.10.00': 'Urea',
    '3102.80.00.00': 'Nitrato de calcio'
}

# Nueva fila
fertilizantes_2024['Tipo de Fertilizante'] = fertilizantes_2024['POSICION ARANCELARIA'].map(mapeo_posiciones)

# Verifico el resultado
print("Muestra de la asignación de tipos de fertilizantes:")
print(fertilizantes_2024[['POSICION ARANCELARIA', 'Tipo de Fertilizante']].head(10))

# Sumo por tipo de fertilizante (agrupando los que son iguales)
volumen_por_tipo = fertilizantes_2024.groupby('Tipo de Fertilizante')['Volumen Total en KGS'].sum().sort_values(ascending=False)

# Convierto en Data Frame
volumen_tipo_df = volumen_por_tipo.reset_index()
volumen_tipo_df.columns = ['Tipo de Fertilizante', 'Volumen Total en KGS']

# Calculo el porcentaje
total_volumen = volumen_tipo_df['Volumen Total en KGS'].sum()
volumen_tipo_df['Porcentaje (%)'] = (volumen_tipo_df['Volumen Total en KGS'] / total_volumen * 100).round(2)

print(volumen_tipo_df)
# Out:
# Muestra de la asignación de tipos de fertilizantes:
#   POSICION ARANCELARIA Tipo de Fertilizante
# 0        3102.50.00.00                 Urea
# 1        3102.10.90.00                 Urea
# 2        3102.10.90.00                 Urea
# 3        3102.60.00.00         Nitrogenados
# 4        3102.10.90.00                 Urea
# 5        3102.60.00.00         Nitrogenados
# 6        3102.21.00.00    Sulfato de Amonio
# 7        3102.90.90.00         Nitrogenados
# 8        3102.90.90.00         Nitrogenados
# 9        3102.90.90.00         Nitrogenados
#   Tipo de Fertilizante  Volumen Total en KGS  Porcentaje (%)
# 0                 Urea          2.783031e+08           47.75
# 1    Sulfato de Amonio          2.380681e+08           40.84
# 2         Nitrogenados          6.648605e+07           11.41
# 3    Nitrato de calcio          8.672000e+03            0.00

# %% [markdown]
# Ahora guardamos estos resultados en un DataFrame

# %%
# Guardar el DataFrame con los resultados
resultado_mercado_fertilizantes_2024_porcentaje = volumen_tipo_df.copy()

# %%
resultado_mercado_fertilizantes_2024_porcentaje
# Out:
#   Tipo de Fertilizante  Volumen Total en KGS  Porcentaje (%)
# 0                 Urea          2.783031e+08           47.75
# 1    Sulfato de Amonio          2.380681e+08           40.84
# 2         Nitrogenados          6.648605e+07           11.41
# 3    Nitrato de calcio          8.672000e+03            0.00

# %%
resultado_mercado_fertilizantes_2024_porcentaje.to_csv('Data_2/resultado_mercado_fertilizantes_2024_porcentaje.csv', index=False)

# %% [markdown]
# Ahora vamos a importar un DataSet del clima en coordenadas de Guayaquil, desde el 2009 hasta 2024

# %%
clima_1 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2009/84117099999.csv')
clima_2 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/84117099999.csv')
clima_3 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/84117099999.csv')
clima_4 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/84117099999.csv')
clima_5 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2013/84117099999.csv')
clima_6 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2014/84117099999.csv')
clima_7 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2015/84117099999.csv')
clima_8 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2016/84117099999.csv')
clima_9 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2017/84117099999.csv')
clima_10 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2018/84117099999.csv')
clima_11 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2019/84117099999.csv')
clima_12 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2020/84117099999.csv')
clima_13 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2021/84117099999.csv')
clima_14 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2022/84117099999.csv')
clima_15 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2023/84117099999.csv')
clima_16 = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2024/84117099999.csv')


pd.options.display.max_columns = None

clima_1
clima_16
# Out:
#          STATION        DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 0    84117099999  2024-01-01     -0.95 -80.683333      14.63
# 1    84117099999  2024-01-02     -0.95 -80.683333      14.63
# 2    84117099999  2024-01-03     -0.95 -80.683333      14.63
# 3    84117099999  2024-01-04     -0.95 -80.683333      14.63
# 4    84117099999  2024-01-05     -0.95 -80.683333      14.63
# ..           ...         ...       ...        ...        ...
# 351  84117099999  2024-12-27     -0.95 -80.683333      14.63
# 352  84117099999  2024-12-28     -0.95 -80.683333      14.63
# 353  84117099999  2024-12-29     -0.95 -80.683333      14.63
# 354  84117099999  2024-12-30     -0.95 -80.683333      14.63
# 355  84117099999  2024-12-31     -0.95 -80.683333      14.63
#
#                               NAME  TEMP  TEMP_ATTRIBUTES  DEWP  \
# 0    ELOY ALFARO INTERNATIONAL, EC  79.3               24  72.3
# 1    ELOY ALFARO INTERNATIONAL, EC  79.2               21  72.1
# 2    ELOY ALFARO INTERNATIONAL, EC  80.0               23  71.8
# 3    ELOY ALFARO INTERNATIONAL, EC  78.9               23  72.3
# 4    ELOY ALFARO INTERNATIONAL, EC  79.1               22  72.5
# ..                             ...   ...              ...   ...
# 351  ELOY ALFARO INTERNATIONAL, EC  80.8               24  68.7
# 352  ELOY ALFARO INTERNATIONAL, EC  79.9               24  69.1
# 353  ELOY ALFARO INTERNATIONAL, EC  77.2               23  71.6
# 354  ELOY ALFARO INTERNATIONAL, EC  78.3               23  70.4
# 355  ELOY ALFARO INTERNATIONAL, EC  78.1               23  69.5
#
#      DEWP_ATTRIBUTES     SLP  SLP_ATTRIBUTES    STP  STP_ATTRIBUTES  VISIB  \
# 0                 24  9999.9               0  999.9               0    6.2
# 1                 21  9999.9               0  999.9               0    6.2
# 2                 23  1011.0               8    9.2               8    6.2
# 3                 23  1011.6               5    9.8               5    6.2
# 4                 22  1011.0               4    9.2               4    6.2
# ..               ...     ...             ...    ...             ...    ...
# 351               24  1010.3               4    8.5               4    6.2
# 352               24  9999.9               0  999.9               0    6.2
# 353               23  9999.9               0  999.9               0    6.2
# 354               23  9999.9               0  999.9               0    6.2
# 355               23  1010.8               4    9.0               4    6.2
#
#      VISIB_ATTRIBUTES  WDSP  WDSP_ATTRIBUTES  MXSPD   GUST   MAX  \
# 0                  23   6.8               23   13.0  999.9  84.2
# 1                  21   7.5               21   11.1  999.9  85.8
# 2                  23   7.9               23   12.0  999.9  87.3
# 3                  23   5.8               23   13.0  999.9  84.9
# 4                  20   6.4               22   11.1  999.9  84.2
# ..                ...   ...              ...    ...    ...   ...
# 351                24   9.1               24   14.0  999.9  90.1
# 352                24   6.1               24   12.0  999.9  89.2
# 353                23   5.0               23    8.0  999.9  85.8
# 354                23   5.8               23    8.9  999.9  84.2
# 355                23   7.3               23   13.0  999.9  84.9
#
#     MAX_ATTRIBUTES   MIN MIN_ATTRIBUTES  PRCP PRCP_ATTRIBUTES   SNDP  FRSHTT
# 0                *  75.2              *  0.00               I  999.9       0
# 1                   75.2              *  0.00               I  999.9       0
# 2                   75.6                 0.00               I  999.9       0
# 3                   74.5                 0.00               B  999.9       0
# 4                *  74.5                 0.00               I  999.9       0
# ..             ...   ...            ...   ...             ...    ...     ...
# 351                 75.2              *  0.00               I  999.9       0
# 352                 75.0                 0.00               I  999.9       0
# 353                 73.4              *  0.08               G  999.9   10000
# 354              *  74.7                 0.00               G  999.9       0
# 355                 75.2              *  0.00               I  999.9       0
#
# [356 rows x 28 columns]

# %% [markdown]
# Ahora juntamos las tablas de todos los años en un unico dataset.

# %%
data_total_clima = pd.concat([clima_1, clima_2, clima_3, clima_4, clima_5, clima_6, clima_7, clima_8, clima_9, clima_10, clima_11, clima_12, clima_13, clima_14, clima_15, clima_16,], 
                       axis=0,           
                       ignore_index=True) 

data_total_clima
# Out:
#           STATION        DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 0     84117099999  2009-01-01     -0.95 -80.683333      14.63
# 1     84117099999  2009-01-02     -0.95 -80.683333      14.63
# 2     84117099999  2009-01-03     -0.95 -80.683333      14.63
# 3     84117099999  2009-01-04     -0.95 -80.683333      14.63
# 4     84117099999  2009-01-05     -0.95 -80.683333      14.63
# ...           ...         ...       ...        ...        ...
# 5800  84117099999  2024-12-27     -0.95 -80.683333      14.63
# 5801  84117099999  2024-12-28     -0.95 -80.683333      14.63
# 5802  84117099999  2024-12-29     -0.95 -80.683333      14.63
# 5803  84117099999  2024-12-30     -0.95 -80.683333      14.63
# 5804  84117099999  2024-12-31     -0.95 -80.683333      14.63
#
#                                NAME  TEMP  TEMP_ATTRIBUTES  DEWP  \
# 0     ELOY ALFARO INTERNATIONAL, EC  76.1               24  67.3
# 1     ELOY ALFARO INTERNATIONAL, EC  77.8               19  65.8
# 2     ELOY ALFARO INTERNATIONAL, EC  78.7               22  67.0
# 3     ELOY ALFARO INTERNATIONAL, EC  77.5               23  67.5
# 4     ELOY ALFARO INTERNATIONAL, EC  79.3               22  67.7
# ...                             ...   ...              ...   ...
# 5800  ELOY ALFARO INTERNATIONAL, EC  80.8               24  68.7
# 5801  ELOY ALFARO INTERNATIONAL, EC  79.9               24  69.1
# 5802  ELOY ALFARO INTERNATIONAL, EC  77.2               23  71.6
# 5803  ELOY ALFARO INTERNATIONAL, EC  78.3               23  70.4
# 5804  ELOY ALFARO INTERNATIONAL, EC  78.1               23  69.5
#
#       DEWP_ATTRIBUTES     SLP  SLP_ATTRIBUTES    STP  STP_ATTRIBUTES  VISIB  \
# 0                  24  9999.9               0  999.9               0    7.0
# 1                  19  9999.9               0  999.9               0    7.0
# 2                  22  9999.9               0  999.9               0    7.0
# 3                  23  9999.9               0  999.9               0    6.9
# 4                  22  9999.9               0  999.9               0    7.0
# ...               ...     ...             ...    ...             ...    ...
# 5800               24  1010.3               4    8.5               4    6.2
# 5801               24  9999.9               0  999.9               0    6.2
# 5802               23  9999.9               0  999.9               0    6.2
# 5803               23  9999.9               0  999.9               0    6.2
# 5804               23  1010.8               4    9.0               4    6.2
#
#       VISIB_ATTRIBUTES  WDSP  WDSP_ATTRIBUTES  MXSPD   GUST   MAX  \
# 0                   24   5.8               24   14.0  999.9  80.6
# 1                   19   7.9               19   14.0  999.9  82.4
# 2                   22   7.3               22   12.0  999.9  82.4
# 3                   23   5.2               23    8.9  999.9  84.2
# 4                   22   8.4               22   15.9  999.9  82.4
# ...                ...   ...              ...    ...    ...   ...
# 5800                24   9.1               24   14.0  999.9  90.1
# 5801                24   6.1               24   12.0  999.9  89.2
# 5802                23   5.0               23    8.0  999.9  85.8
# 5803                23   5.8               23    8.9  999.9  84.2
# 5804                23   7.3               23   13.0  999.9  84.9
#
#      MAX_ATTRIBUTES   MIN MIN_ATTRIBUTES   PRCP PRCP_ATTRIBUTES   SNDP  FRSHTT
# 0                 *  69.8              *   0.00               I  999.9       0
# 1                 *  75.2              *   0.00               I  999.9       0
# 2                 *  75.2              *   0.00               I  999.9       0
# 3                 *  73.4              *  99.99                  999.9   10000
# 4                 *  77.0              *   0.00               I  999.9       0
# ...             ...   ...            ...    ...             ...    ...     ...
# 5800                 75.2              *   0.00               I  999.9       0
# 5801                 75.0                  0.00               I  999.9       0
# 5802                 73.4              *   0.08               G  999.9   10000
# 5803              *  74.7                  0.00               G  999.9       0
# 5804                 75.2              *   0.00               I  999.9       0
#
# [5805 rows x 28 columns]

# %% [markdown]
# Ahora voy a escoger solo las columnas que me convienen. Fecha, temperatura y precipitacion.

# %%
data_total_clima_2 = ['DATE', 'LATITUDE',
       'LONGITUDE', 'NAME', 'TEMP', 'PRCP']
data_total_clima = data_total_clima[data_total_clima_2]

data_total_clima
# Out:
#             DATE  LATITUDE  LONGITUDE                           NAME  TEMP  \
# 0     2009-01-01     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  76.1
# 1     2009-01-02     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  77.8
# 2     2009-01-03     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  78.7
# 3     2009-01-04     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  77.5
# 4     2009-01-05     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  79.3
# ...          ...       ...        ...                            ...   ...
# 5800  2024-12-27     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  80.8
# 5801  2024-12-28     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  79.9
# 5802  2024-12-29     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  77.2
# 5803  2024-12-30     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  78.3
# 5804  2024-12-31     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  78.1
#
#        PRCP
# 0      0.00
# 1      0.00
# 2      0.00
# 3     99.99
# 4      0.00
# ...     ...
# 5800   0.00
# 5801   0.00
# 5802   0.08
# 5803   0.00
# 5804   0.00
#
# [5805 rows x 6 columns]

# %% [markdown]
# Ahora voy a revisar cada columna.

# %%
# Empezamos por DATE

# %%
len(data_total_clima[data_total_clima['DATE'] == '0000-00-00'])
# Out:
# 0

# %%
data_total_clima['DATE'].value_counts()
# Out:
# DATE
# 2009-01-01    1
# 2019-08-31    1
# 2019-08-29    1
# 2019-08-28    1
# 2019-08-27    1
#              ..
# 2014-04-28    1
# 2014-04-27    1
# 2014-04-26    1
# 2014-04-25    1
# 2024-12-31    1
# Name: count, Length: 5805, dtype: int64

# %%
data_total_clima['DATE'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Ahora revisamos LATITUDE

# %%
data_total_clima['LATITUDE'].value_counts()
# Out:
# LATITUDE
# -0.95    5805
# Name: count, dtype: int64

# %%
data_total_clima['LATITUDE'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Ahora buscamos Ahora

# %%
data_total_clima['NAME'].value_counts()
# Out:
# NAME
# ELOY ALFARO INTERNATIONAL, EC    5805
# Name: count, dtype: int64

# %%
data_total_clima['NAME'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Ahora revisamos TEMP

# %%
data_total_clima['TEMP'].value_counts()
# Out:
# TEMP
# 79.6    99
# 78.6    99
# 78.9    95
# 76.1    88
# 79.5    88
#         ..
# 82.9     1
# 83.7     1
# 68.8     1
# 69.6     1
# 86.9     1
# Name: count, Length: 139, dtype: int64

# %%
data_total_clima['TEMP'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Ahora revisamos PRCP

# %%
data_total_clima['PRCP'].value_counts()
# Out:
# PRCP
# 0.00     5028
# 99.99     188
# 0.02       78
# 0.04       71
# 0.01       71
# 0.08       64
# 0.12       40
# 0.03       34
# 0.16       30
# 0.20       23
# 0.24       22
# 0.31       18
# 0.28       18
# 0.35       10
# 0.51        9
# 0.43        9
# 0.39        7
# 0.47        7
# 0.71        6
# 0.55        5
# 0.59        5
# 1.18        4
# 1.10        4
# 1.02        3
# 0.79        3
# 1.85        2
# 0.63        2
# 0.87        2
# 0.94        2
# 1.89        2
# 0.83        2
# 1.14        2
# 2.36        2
# 0.98        2
# 1.81        2
# 0.91        2
# 0.67        2
# 1.77        2
# 1.61        1
# 2.28        1
# 0.17        1
# 0.09        1
# 2.20        1
# 2.68        1
# 1.50        1
# 5.99        1
# 0.75        1
# 3.07        1
# 3.23        1
# 2.60        1
# 1.38        1
# 1.46        1
# 2.09        1
# 1.30        1
# 1.65        1
# 2.24        1
# 2.64        1
# 1.26        1
# 1.22        1
# 7.13        1
# Name: count, dtype: int64

# %%
data_total_clima['PRCP'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Ahora cambio la columna DATE por FECHA, para que cuadre con el dataframe anterior

# %%
data_total_clima = data_total_clima.rename(columns={'DATE': 'FECHA'})

# %%
data_total_clima
# Out:
#            FECHA  LATITUDE  LONGITUDE                           NAME  TEMP  \
# 0     2009-01-01     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  76.1
# 1     2009-01-02     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  77.8
# 2     2009-01-03     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  78.7
# 3     2009-01-04     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  77.5
# 4     2009-01-05     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  79.3
# ...          ...       ...        ...                            ...   ...
# 5800  2024-12-27     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  80.8
# 5801  2024-12-28     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  79.9
# 5802  2024-12-29     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  77.2
# 5803  2024-12-30     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  78.3
# 5804  2024-12-31     -0.95 -80.683333  ELOY ALFARO INTERNATIONAL, EC  78.1
#
#        PRCP
# 0      0.00
# 1      0.00
# 2      0.00
# 3     99.99
# 4      0.00
# ...     ...
# 5800   0.00
# 5801   0.00
# 5802   0.08
# 5803   0.00
# 5804   0.00
#
# [5805 rows x 6 columns]

# %% [markdown]
# Cambio el formato de Fecha

# %%
data_total_clima['FECHA'] = pd.to_datetime(data_total_clima['FECHA'], format="%Y-%m-%d")

# %%
data_total_clima.to_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data_2/clima_si/data_total_clima.csv')

# %%
data_total_clima_filtrada = data_total_clima[["FECHA", "PRCP"]]

# %%
data_total_clima_filtrada
# Out:
#           FECHA   PRCP
# 0    2009-01-01   0.00
# 1    2009-01-02   0.00
# 2    2009-01-03   0.00
# 3    2009-01-04  99.99
# 4    2009-01-05   0.00
# ...         ...    ...
# 5800 2024-12-27   0.00
# 5801 2024-12-28   0.00
# 5802 2024-12-29   0.08
# 5803 2024-12-30   0.00
# 5804 2024-12-31   0.00
#
# [5805 rows x 2 columns]

# %%
data_total_clima_filtrada["PRCP"].value_counts()
# Out:
# PRCP
# 0.00     5028
# 99.99     188
# 0.02       78
# 0.04       71
# 0.01       71
# 0.08       64
# 0.12       40
# 0.03       34
# 0.16       30
# 0.20       23
# 0.24       22
# 0.31       18
# 0.28       18
# 0.35       10
# 0.51        9
# 0.43        9
# 0.39        7
# 0.47        7
# 0.71        6
# 0.55        5
# 0.59        5
# 1.18        4
# 1.10        4
# 1.02        3
# 0.79        3
# 1.85        2
# 0.63        2
# 0.87        2
# 0.94        2
# 1.89        2
# 0.83        2
# 1.14        2
# 2.36        2
# 0.98        2
# 1.81        2
# 0.91        2
# 0.67        2
# 1.77        2
# 1.61        1
# 2.28        1
# 0.17        1
# 0.09        1
# 2.20        1
# 2.68        1
# 1.50        1
# 5.99        1
# 0.75        1
# 3.07        1
# 3.23        1
# 2.60        1
# 1.38        1
# 1.46        1
# 2.09        1
# 1.30        1
# 1.65        1
# 2.24        1
# 2.64        1
# 1.26        1
# 1.22        1
# 7.13        1
# Name: count, dtype: int64

# %% [markdown]
# Ordenamos por fecha los valores donde la precipitacion es mayor a 0.00

# %%
# Filtrar días con precipitación y ordenar por fecha. Tener en cuenta que una precipitacion se toma como apreciable si tiene un ratio mayor a 5
dias_con_lluvia = data_total_clima_filtrada[data_total_clima_filtrada['PRCP'] > 5.00]
dias_con_lluvia['FECHA'] = pd.to_datetime(dias_con_lluvia['FECHA'])
dias_lluvia = dias_con_lluvia.sort_values('FECHA')

dias_lluvia
# Out:
# /var/folders/9d/njcmv3bs67bgg_6p6s5pyjsw0000gn/T/ipykernel_3028/7602807.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dias_con_lluvia['FECHA'] = pd.to_datetime(dias_con_lluvia['FECHA'])
#           FECHA   PRCP
# 3    2009-01-04  99.99
# 7    2009-01-08  99.99
# 9    2009-01-10  99.99
# 12   2009-01-13  99.99
# 13   2009-01-14  99.99
# ...         ...    ...
# 5467 2024-01-19  99.99
# 5485 2024-02-06  99.99
# 5552 2024-04-17  99.99
# 5599 2024-06-03   7.13
# 5786 2024-12-13  99.99
#
# [190 rows x 2 columns]

# %% [markdown]
# Guardo los dias con mas precipitacion

# %%
dias_lluvia.to_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data_2/clima_si/dias_lluvia.csv')

# %% [markdown]
# Ahora sacamos promedio de precipitacion mes a mes

# %%
data_total_clima_filtrada['Año'] = data_total_clima_filtrada['FECHA'].dt.year
data_total_clima_filtrada['Mes'] = data_total_clima_filtrada['FECHA'].dt.month

# Calculo por año y por mes
promedio_prcp_por_año_mes = data_total_clima_filtrada.groupby(['Año', 'Mes'])['PRCP'].mean().reset_index()
promedio_prcp_por_año_mes.columns = ['Año', 'Mes', 'Promedio PRCP']

# Y ordeno
promedio_prcp_por_año_mes = promedio_prcp_por_año_mes.sort_values(['Año', 'Mes'])

promedio_prcp_por_año_mes
# Out:
# /var/folders/9d/njcmv3bs67bgg_6p6s5pyjsw0000gn/T/ipykernel_3028/3928281582.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total_clima_filtrada['Año'] = data_total_clima_filtrada['FECHA'].dt.year
# /var/folders/9d/njcmv3bs67bgg_6p6s5pyjsw0000gn/T/ipykernel_3028/3928281582.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total_clima_filtrada['Mes'] = data_total_clima_filtrada['FECHA'].dt.month
#       Año  Mes  Promedio PRCP
# 0    2009    1      25.808065
# 1    2009    2      10.744286
# 2    2009    3       0.029355
# 3    2009    4       6.666000
# 4    2009    5       9.676452
# ..    ...  ...            ...
# 187  2024    8       0.000000
# 188  2024    9       0.000000
# 189  2024   10       0.000000
# 190  2024   11       0.000000
# 191  2024   12       3.229677
#
# [192 rows x 3 columns]

# %% [markdown]
# Guardo

# %%
promedio_prcp_por_año_mes.to_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data_2/clima_si/promedio_prcp_por_año_mes.csv')

# %% [markdown]
# Y por si es de utilidad guardo la data filtrada, que va dia a dia pero solo con precipitacion

# %%
data_total_clima_filtrada.to_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data_2/clima_si/data_total_clima_filtrada.csv')

# %% [markdown]
# <h1>Precios historicos</h1>

# %% [markdown]
# Empezamos por urea

# %%
data_1_precio_urea = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data /Precios historicos UREA/Urea Granular FOB Middle East Futures Historical Data.csv")

# %%
data_1_precio_urea
# Out:
#             Date   Price    Open    High     Low   Vol. Change %
# 0     12/31/2024  369.00  369.00  369.00  369.00    NaN    0.00%
# 1     12/30/2024  369.00  369.00  369.00  369.00    NaN    0.00%
# 2     12/27/2024  369.00  369.00  369.00  369.00    NaN    0.82%
# 3     12/26/2024  366.00  366.00  366.00  366.00    NaN    0.00%
# 4     12/24/2024  366.00  366.00  366.00  366.00    NaN    0.00%
# ...          ...     ...     ...     ...     ...    ...      ...
# 1825  07/03/2017  186.50  186.50  186.50  186.50    NaN   -0.27%
# 1826  06/30/2017  187.00  187.00  187.00  187.00    NaN    0.40%
# 1827  06/29/2017  186.25  186.25  186.25  186.25  0.05K    0.13%
# 1828  06/28/2017  186.00  186.00  186.00  186.00    NaN   -0.13%
# 1829  06/27/2017  186.25  186.25  186.25  186.25    NaN   -0.53%
#
# [1830 rows x 7 columns]

# %% [markdown]
# Primero renombro la columna Date a FECHA para que cuadre con los otros.

# %%
data_1_precio_urea = data_1_precio_urea.rename(columns={'Date': 'FECHA'})

# %%
data_1_precio_urea
# Out:
#            FECHA   Price    Open    High     Low   Vol. Change %
# 0     12/31/2024  369.00  369.00  369.00  369.00    NaN    0.00%
# 1     12/30/2024  369.00  369.00  369.00  369.00    NaN    0.00%
# 2     12/27/2024  369.00  369.00  369.00  369.00    NaN    0.82%
# 3     12/26/2024  366.00  366.00  366.00  366.00    NaN    0.00%
# 4     12/24/2024  366.00  366.00  366.00  366.00    NaN    0.00%
# ...          ...     ...     ...     ...     ...    ...      ...
# 1825  07/03/2017  186.50  186.50  186.50  186.50    NaN   -0.27%
# 1826  06/30/2017  187.00  187.00  187.00  187.00    NaN    0.40%
# 1827  06/29/2017  186.25  186.25  186.25  186.25  0.05K    0.13%
# 1828  06/28/2017  186.00  186.00  186.00  186.00    NaN   -0.13%
# 1829  06/27/2017  186.25  186.25  186.25  186.25    NaN   -0.53%
#
# [1830 rows x 7 columns]

# %% [markdown]
# Ahora cambiamos la estructura de las fechas

# %%
data_1_precio_urea['FECHA'] = pd.to_datetime(data_1_precio_urea['FECHA']).dt.strftime('%Y-%m-%d')

# %% [markdown]
# Ahora removemos las columnas innutiles

# %%
data_1_precio_urea_filtrada = data_1_precio_urea.drop(columns=['Open', 'High', 'Low', 'Vol.'])

# %%
data_1_precio_urea_filtrada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1830 entries, 0 to 1829
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   FECHA     1830 non-null   datetime64[ns]
#  1   Price     1830 non-null   float64
#  2   Change %  1830 non-null   object
#  3   Año       1830 non-null   int32
#  4   Mes       1830 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(2), object(1)
# memory usage: 57.3+ KB

# %%
data_1_precio_urea_filtrada.to_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data_2/precios_historicos/data_1_precio_urea_filtrada.csv', index=False)

# %% [markdown]
# Ahora que tenemos el dia a dia de la Urea, vamos a sacar el precio y el % change por ano y mes

# %%
# # Convierto para que me pueda servir, aunque ya esta como date
data_1_precio_urea_filtrada['FECHA'] = pd.to_datetime(data_1_precio_urea_filtrada['FECHA'])

data_1_precio_urea_filtrada['Año'] = data_1_precio_urea_filtrada['FECHA'].dt.year
data_1_precio_urea_filtrada['Mes'] = data_1_precio_urea_filtrada['FECHA'].dt.month

# Cmabio change de object a numeric y remuevo cualquier %
if data_1_precio_urea_filtrada['Change %'].dtype == 'object':
    data_1_precio_urea_filtrada['Change %'] = data_1_precio_urea_filtrada['Change %'].str.replace('%', '')
    data_1_precio_urea_filtrada['Change %'] = data_1_precio_urea_filtrada['Change %'].str.replace(',', '.')
    data_1_precio_urea_filtrada['Change %'] = pd.to_numeric(data_1_precio_urea_filtrada['Change %'], errors='coerce')

# Calculo el mean de price y change por mes
promedio_precio_por_mes_urea = data_1_precio_urea_filtrada.groupby(['Año', 'Mes']).agg({
    'Price': 'mean',
    'Change %': 'mean'
}).reset_index()

promedio_precio_por_mes_urea.columns = ['Year', 'Month', 'Mean Price', 'Mean Change%']

promedio_precio_por_mes_urea['Mean Price'] = promedio_precio_por_mes_urea['Mean Price'].apply(lambda x: f"{x:.2f}")

promedio_precio_por_mes_urea['Mean Change%'] = promedio_precio_por_mes_urea['Mean Change%'].apply(lambda x: f"{x:.2f}%")

promedio_precio_por_mes_urea = promedio_precio_por_mes_urea.sort_values(['Year', 'Month'])

promedio_precio_por_mes_urea
# Out:
#     Year  Month Mean Price Mean Change%
# 0   2017      6     186.38       -0.03%
# 1   2017      7     186.30        0.28%
# 2   2017      8     209.76        0.37%
# 3   2017      9     243.25        1.07%
# 4   2017     10     279.27        0.48%
# ..   ...    ...        ...          ...
# 86  2024      8     339.00       -0.16%
# 87  2024      9     337.08        0.35%
# 88  2024     10     369.99        0.18%
# 89  2024     11     354.02       -0.35%
# 90  2024     12     353.18        0.35%
#
# [91 rows x 4 columns]

# %% [markdown]
# Guardo el promedio de urea por mes

# %%
promedio_precio_por_mes_urea.to_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data_2/precios_historicos/promedio_precio_por_mes_urea.csv', index=False)

# %% [markdown]
# Ahora voy a transferir los datos del precio del ETF de Gas Natural

# %%
data_1_precio_nat_gas = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data /Precios Historicos Nat Gas/FCG ETF Stock Price History.csv")

# %%
data_1_precio_nat_gas
# Out:
#             Date  Price   Open   High    Low     Vol. Change %
# 0     03/28/2025  24.64  24.70  24.80  24.43  140.47K   -0.61%
# 1     03/27/2025  24.79  24.96  25.05  24.66  197.88K   -1.78%
# 2     03/26/2025  25.24  25.37  25.62  25.18  133.59K    0.24%
# 3     03/25/2025  25.18  25.20  25.38  25.07  326.65K    0.16%
# 4     03/24/2025  25.14  24.83  25.23  24.83  183.09K    1.66%
# ...          ...    ...    ...    ...    ...      ...      ...
# 4110  01/08/2009  66.10  65.10  66.10  63.96    8.01K    0.99%
# 4111  01/07/2009  65.45  68.60  68.65  64.42    7.67K   -4.24%
# 4112  01/06/2009  68.35  67.50  69.70  67.50    8.56K    3.09%
# 4113  01/05/2009  66.30  63.60  67.15  63.60   16.09K    5.66%
# 4114  01/02/2009  62.75  59.40  63.33  59.40    8.29K    6.54%
#
# [4115 rows x 7 columns]

# %% [markdown]
# Empezamos cambiando la columna de Date  Fecha

# %%
data_1_precio_nat_gas = data_1_precio_nat_gas.rename(columns={'Date': 'FECHA'})

# %% [markdown]
# Ahora cambiaremos la estructura de las fechas

# %%
data_1_precio_nat_gas['FECHA'] = pd.to_datetime(data_1_precio_nat_gas['FECHA']).dt.strftime('%Y-%m-%d')

# %% [markdown]
# Removemos las columnas innutiles

# %%
data_1_precio_nat_gas_filtrado = data_1_precio_nat_gas.drop(columns=['Open', 'High', 'Low', 'Vol.'])

# %% [markdown]
# Guardamos esta data de todos los dias

# %%
data_1_precio_nat_gas_filtrado.to_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data_2/precios_historicos/data_1_precio_nat_gas_filtrado.csv', index=False)

# %%
# Seguimos el mismo proceso anterior
data_1_precio_nat_gas_filtrado['FECHA'] = pd.to_datetime(data_1_precio_nat_gas_filtrado['FECHA'])

data_1_precio_nat_gas_filtrado['Año'] = data_1_precio_nat_gas_filtrado['FECHA'].dt.year
data_1_precio_nat_gas_filtrado['Mes'] = data_1_precio_nat_gas_filtrado['FECHA'].dt.month

if data_1_precio_nat_gas_filtrado['Change %'].dtype == 'object':
    data_1_precio_nat_gas_filtrado['Change %'] = data_1_precio_nat_gas_filtrado['Change %'].str.replace('%', '')
    data_1_precio_nat_gas_filtrado['Change %'] = data_1_precio_nat_gas_filtrado['Change %'].str.replace(',', '.')
    data_1_precio_nat_gas_filtrado['Change %'] = pd.to_numeric(data_1_precio_nat_gas_filtrado['Change %'], errors='coerce')

promedio_precio_por_mes_gas = data_1_precio_nat_gas_filtrado.groupby(['Año', 'Mes']).agg({
    'Price': 'mean',
    'Change %': 'mean'
}).reset_index()

promedio_precio_por_mes_gas.columns = ['Año', 'Mes', 'Mean Precio', 'Mean Cambio%']

promedio_precio_por_mes_gas['Mean Precio'] = promedio_precio_por_mes_gas['Mean Precio'].apply(lambda x: f"{x:.2f}")

promedio_precio_por_mes_gas['Mean Cambio%'] = promedio_precio_por_mes_gas['Mean Cambio%'].apply(lambda x: f"{x:.2f}%")

promedio_precio_por_mes_gas = promedio_precio_por_mes_gas.sort_values(['Año', 'Mes'])

promedio_precio_por_mes_gas
# Out:
#       Año  Mes Mean Precio Mean Cambio%
# 0    2009    1       60.78        0.07%
# 1    2009    2       56.80       -0.80%
# 2    2009    3       48.68        0.11%
# 3    2009    4       56.98        0.97%
# 4    2009    5       67.55        1.02%
# ..    ...  ...         ...          ...
# 190  2024   11       25.30        0.53%
# 191  2024   12       24.35       -0.27%
# 192  2025    1       25.98        0.06%
# 193  2025    2       25.06       -0.10%
# 194  2025    3       23.95        0.08%
#
# [195 rows x 4 columns]

# %%
promedio_precio_por_mes_gas.to_csv('/Users/auric/REPO_TEST/Entregas/Entrega 28 - 03 de abril de marzo/EDA Agricultura_Clima Ecuador/EDA/Data_2/precios_historicos/promedio_precio_por_mes_gas.csv', index=False)
