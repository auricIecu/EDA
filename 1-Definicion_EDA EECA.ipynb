# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Afectaciones climatica y eventos macroeconomicos en la agricultura ecuatoriana"

# %% [markdown]
# ### TEMA

# %% [markdown]
# Mi tema intenta analizar tres factores que influencian a la agricultura de mi país, tomando como muestra la zona de Costa (zona con mayor produccion agricicola del pais, donde se planta todo el banano) y como indicador economico la UREA, fertilizante que mas se consume en estos cultivos. Tomamos en cuenta los precios historicos de la UREA y los precios y cantidades de las importaciones de UREA al Ecuador.
#
# Los factores son:
#
# -El clima (muy volatil en una ciudad tropical, con lluvias fuertes en tres meses del año y sequia en los demas)
#
# -Los volumenes de importacion al pais.
#
# -Eventos macroeconomicos que hayan influenciado en la volatilidad de precio de esta commoditie. (Por ejemplo la guerra de Rusia)

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# Hipotesis principal:
#
# -Los factores climáticos, los volúmenes de importación y los eventos macroeconómicos globales explican de manera significativa la variabilidad en los precios históricos de la urea y su impacto en la productividad agrícola de la zona de la Costa de Ecuador.

# %% [markdown]
# Sub-hipotesis:
#
# -La variacion en las precipitaciones fuertes en la Costa de Ecuador (enero-marzo) impactan directamente los volumenes de importacion a lo largo del ano.
#
# -Eventos macroeconómicos globales, como la guerra entre Rusia y Ucrania iniciada en 2022, han incrementado la volatilidad de los precios internacionales de la urea, impactando directamente los costos agrícolas.
#
# -Los eventos macroeconomicos han tenido un impacto en la supply chain de la UREA hacia Ecuador, afectando directamente los costos de FLETE.
#
# -La guerra de Rusia lo ha acentado como principal partner de Urea de Ecuador.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import numpy as np
import pandas as pd

# guarda en variables los datasets y su fuente
df_1 = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 de marzo/EDA Agricultura_Clima Ecuador/EDA/Data/data_total_urea.csv") 
fuente_1 = "https://www.cobusecuador.ec"
df_2 = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 de marzo/EDA Agricultura_Clima Ecuador/EDA/Data/data_total_clima.csv") 
fuente_2 = "https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/"
df_3 = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 de marzo/EDA Agricultura_Clima Ecuador/EDA/Data/data_total_urea.csv") 
fuente_3 = "https://www.investing.com/commodities/urea-granular-fob-middle-east-futures"

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Dataset que muestra importaciones, con clima.
df_f_1 = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 de marzo/EDA Agricultura_Clima Ecuador/EDA/Data/merged_data_urea_clima.csv") 
df_f_1()
# Out:
#       Unnamed: 0                                      RAZON SOCIAL  \
# 0              0  QUIMICA INDUSTRIAL MONTALVO AGUILAR QUIMASA S.A.
# 1              1                                      DELCORP S.A.
# 2              2                                      AGRIPAC S.A.
# 3              3                                     FERMAGRI S.A.
# 4              4                                      DELCORP S.A.
# ...          ...                                               ...
# 1935        1935                                   PRECISAGRO S.A.
# 1936        1936                                   PRECISAGRO S.A.
# 1937        1937                               YARECUADOR CIA LTDA
# 1938        1938                               YARECUADOR CIA LTDA
# 1939        1939  QUIMICA INDUSTRIAL MONTALVO AGUILAR QUIMASA S.A.
#
#            FECHA          PAIS ORIGEN VIA TRANSPORTE PAIS DESTINO     FOB U$S  \
# 0     2011-11-25                CHINA       MARITIMO      ECUADOR   244324.80
# ...

# %%
# Dataset que muestra importaciones, con clima y precios de la urea.
df_f_2 = pd.read_csv("/Users/auric/REPO_TEST/Entregas/Entrega 28 de marzo/EDA Agricultura_Clima Ecuador/EDA/Data/merge_importaciones_clima_precio.csv") 
df_f_2.head()
# Out:
#    Unnamed: 0                                  RAZON SOCIAL       FECHA  \
# 0           0                   ROGEL JIMENEZ JAIME ENRIQUE  2017-07-06
# 1           1                   ROGEL JIMENEZ JAIME ENRIQUE  2017-07-20
# 2           2                   ROGEL JIMENEZ JAIME ENRIQUE  2017-07-20
# 3           3                   SOTO JIMENEZ ROXI DEL CISNE  2017-07-20
# 4           4  ACABADOS TEXTILES DEL ECUADOR S.A. ACATEXTIL  2017-07-19
#
#           PAIS ORIGEN VIA TRANSPORTE PAIS DESTINO  FOB U$S  FLETE U$S  \
# 0  RUSSIAN FEDERATION      CARRETERA      ECUADOR  5508.00     407.08
# 1  RUSSIAN FEDERATION      CARRETERA      ECUADOR  3900.00     306.60
# 2  RUSSIAN FEDERATION      CARRETERA      ECUADOR  3000.00     235.85
# 3           VENEZUELA      CARRETERA      ECUADOR  2986.75     200.02
# 4            COLOMBIA      CARRETERA      ECUADOR   141.00       5.60
#
#    TOTAL KGS NETO  LATITUDE  LONGITUDE                           NAME  TEMP  \
# ...
